# %%
from db import Session
from models import Product
session = Session()

# %% [markdown]
# In this chapter you are going to learn how to eliminate duplication by creating multiple related tables using one of the fundamental patterns in relational database design: the _one-to-many_ relationship.
