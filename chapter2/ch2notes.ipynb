# %%
import csv

with open('products.csv') as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(row)
# Out:
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'Acorn Atom', 'cpu': '6502', 'year': '1980'}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'BBC Micro', 'cpu': '6502', 'year': '1981'}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'Electron', 'cpu': '6502', 'year': '1983'}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'BBC Master', 'cpu': '65SC12', 'year': '1986'}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'Acorn Archimedes', 'cpu': 'ARM RISC', 'year': '1987'}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'A7000', 'cpu': 'ARM RISC', 'year': '1995'}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'CPC 464', 'cpu': 'Z80', 'year': '1984'}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'CPC 664', 'cpu': 'Z80', 'year': '1984'}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'CPC 6128', 'cpu': 'Z80', 'year': '1984'}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': '464 Plus', 'cpu': 'Z80', 'year': '1990'}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': '6128 Plus', 'cpu': 'Z80', 'year': '1990'}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'PCW', 'cpu': 'Z80', 'year': '1985'}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'PC-1512', 'cpu': '8086', 'year': '1986'}
# {'country': 'China', 'manufacturer': 'Tsinghua University', 'name': 'CEC-I Zhonghua', 'cpu': '6502', 'year': '1986'}
# {'country': 'USA', 'manufacturer': 'APF Electronics, Inc.', 'name': 'Imagination Machine', 'cpu': '6800', 'year': '1979'}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple II', 'cpu': '6502', 'year': '1977'}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple IIe', 'cpu': '6502', 'year': '1983'}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple IIc', 'cpu': '65C02', 'year': '1984'}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple IIc Plus', 'cpu': '65C02', 'year': '1988'}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple II Plus', 'cpu': '6502', 'year': '1979'}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple IIGS', 'cpu': '65C816', 'year': '1986'}
# {'country': 'UK', 'manufacturer': 'Apricot Computers', 'name': 'Apricot F1', 'cpu': '8088', 'year': '1984'}
# {'country': 'Netherlands', 'manufacturer': 'Aster Computers', 'name': 'CT-80', 'cpu': 'Z80', 'year': '1982'}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 400', 'cpu': '6502', 'year': '1979'}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 800', 'cpu': '6502', 'year': '1979'}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 1200XL', 'cpu': '6502', 'year': '1983'}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 600XL', 'cpu': '6502', 'year': '1983'}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 800XL', 'cpu': '6502', 'year': '1983'}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 65XE', 'cpu': '6502C', 'year': '1985'}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 130XE', 'cpu': '6502C', 'year': '1985'}
# {'country': 'USA', 'manufacturer': 'Atari Corporation', 'name': 'Atari ST', 'cpu': '68000', 'year': '1985'}
# {'country': 'USA', 'manufacturer': 'Atari Corporation', 'name': 'Atari TT', 'cpu': '68030', 'year': '1990'}
# {'country': 'USA', 'manufacturer': 'Atari Corporation', 'name': 'Falcon', 'cpu': '68030 + 56001', 'year': '1992'}
# {'country': 'USA', 'manufacturer': 'Bally Consumer Products', 'name': 'Bally Brain', 'cpu': 'Z80', 'year': '1979'}
# {'country': 'USA', 'manufacturer': 'Bally Consumer Products', 'name': 'Bally Astrocade', 'cpu': 'Z80', 'year': '1977'}
# {'country': 'Romania', 'manufacturer': 'Brasov Computer', 'name': 'CoBra', 'cpu': 'Z80', 'year': '1986'}
# {'country': 'UK', 'manufacturer': 'Camputers', 'name': 'Lynx', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'USA', 'manufacturer': 'Coleco', 'name': 'Coleco Adam', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'PET', 'cpu': '6502', 'year': '1977'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'VIC-20', 'cpu': '6502', 'year': '1980'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore 64', 'cpu': '6510', 'year': '1982'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore Executive 64', 'cpu': '6510', 'year': '1982'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'MAX Machine', 'cpu': '6510', 'year': '1982'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore 16', 'cpu': '8501 (6502)', 'year': '1984'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore 116', 'cpu': '8501 (6502)', 'year': '1984'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Plus/4', 'cpu': '8501 (6502)', 'year': '1984'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore 128', 'cpu': '8502 (6502) / Z80', 'year': '1985'}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Amiga', 'cpu': '68000 (family)', 'year': '1985'}
# {'country': 'Hong Kong', 'manufacturer': 'Comx World Operations', 'name': 'Comx-35', 'cpu': 'RCA 1802', 'year': '1983'}
# {'country': 'Belgium', 'manufacturer': 'Data Applications International', 'name': 'DAI Personal Computer', 'cpu': '8080', 'year': '1980'}
# {'country': 'Hong Kong', 'manufacturer': 'Vtech', 'name': 'VTech Laser 200', 'cpu': 'Z80', 'year': '1985'}
# {'country': 'Hong Kong', 'manufacturer': 'EACA', 'name': 'Video Genie', 'cpu': 'Z80', 'year': '1980'}
# {'country': 'Hong Kong', 'manufacturer': 'EACA', 'name': 'Colour Genie', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'Hong Kong', 'manufacturer': 'Rabbit', 'name': 'Rabbit RX83', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'Czechoslovakia', 'manufacturer': 'Didaktik', 'name': 'Alpha', 'cpu': 'Z80', 'year': '1986'}
# {'country': 'Czechoslovakia', 'manufacturer': 'Didaktik', 'name': 'Beta', 'cpu': 'Z80', 'year': '1986'}
# {'country': 'Czechoslovakia', 'manufacturer': 'Didaktik', 'name': 'Gama', 'cpu': 'Z80', 'year': '1987'}
# {'country': 'UK', 'manufacturer': 'Dragon Data', 'name': 'Dragon 32', 'cpu': '6809', 'year': '1982'}
# {'country': 'UK', 'manufacturer': 'Dragon Data', 'name': 'Dragon 64', 'cpu': '6809', 'year': '1982'}
# {'country': 'USSR', 'manufacturer': 'Dubna', 'name': 'Dubna 48K', 'cpu': 'Z80 (compatible)', 'year': '1991'}
# {'country': 'USSR', 'manufacturer': 'Elektronika', 'name': 'BK-0010', 'cpu': 'PDP 11 (compatible)', 'year': '1985'}
# {'country': 'USSR', 'manufacturer': 'AGAT', 'name': 'AGAT-9', 'cpu': 'Native/Apple II compatible', 'year': '1984'}
# {'country': 'Serbia', 'manufacturer': 'Elektronska Industrija Niš', 'name': 'Pecom 32', 'cpu': 'RCA 1802', 'year': '1985'}
# {'country': 'Serbia', 'manufacturer': 'Elektronska Industrija Niš', 'name': 'Pecom 64', 'cpu': 'RCA 1802', 'year': '1985'}
# {'country': 'USA', 'manufacturer': 'Exidy', 'name': 'Exidy Sorcerer', 'cpu': 'Z80', 'year': '1978'}
# {'country': 'UK', 'manufacturer': 'Intelligent Software', 'name': 'Enterprise 64', 'cpu': 'Z80', 'year': '1985'}
# {'country': 'UK', 'manufacturer': 'Intelligent Software', 'name': 'Enterprise 128', 'cpu': 'Z80', 'year': '1985'}
# {'country': 'Hong Kong', 'manufacturer': 'Lambda Electronics', 'name': 'Lambda 8300', 'cpu': 'Z80', 'year': '1985'}
# {'country': 'USA', 'manufacturer': 'Franklin Computer Corporation', 'name': 'Franklin ACE', 'cpu': '6502', 'year': '1982'}
# {'country': 'Japan', 'manufacturer': 'Fujitsu', 'name': 'FM Towns', 'cpu': '80386SX', 'year': '1989'}
# {'country': 'Japan', 'manufacturer': 'Fujitsu', 'name': 'FM-7', 'cpu': '6809', 'year': '1982'}
# {'country': 'UK', 'manufacturer': 'Grundy Business Systems', 'name': 'Grundy NewBrain', 'cpu': 'Z80', 'year': '1982'}
# {'country': 'Brazil', 'manufacturer': 'Gradiente', 'name': 'Gradiente Expert', 'cpu': 'Z80', 'year': '1985'}
# {'country': 'USA', 'manufacturer': 'Honeywell', 'name': 'Honeywell 316', 'cpu': 'DDP 16 Minicomputer', 'year': '1969'}
# {'country': 'USA', 'manufacturer': 'IBM', 'name': 'PCjr', 'cpu': '8088', 'year': '1984'}
# {'country': 'USA', 'manufacturer': 'IBM', 'name': 'IBM PS/1', 'cpu': '8088', 'year': '1990'}
# {'country': 'USA', 'manufacturer': 'Interact', 'name': 'Interact Home Computer', 'cpu': '8080', 'year': '1979'}
# {'country': 'USA', 'manufacturer': 'Intelligent Systems Corporation', 'name': 'Compucolor II', 'cpu': '8080', 'year': '1977'}
# {'country': 'USSR', 'manufacturer': 'Intercompex', 'name': 'Hobbit', 'cpu': 'Z80 compatible', 'year': '1990'}
# {'country': 'USSR', 'manufacturer': 'Iskra', 'name': 'Iskra-1030', 'cpu': '8086 compatible', 'year': '1989'}
# {'country': 'Croatia', 'manufacturer': 'Ivasim', 'name': 'Ivel Ultra', 'cpu': '6502 compatible', 'year': '1984'}
# {'country': 'Croatia', 'manufacturer': 'Ivasim', 'name': 'Ivel Z3', 'cpu': '6502 compatible', 'year': '1983'}
# {'country': 'UK', 'manufacturer': 'Jupiter Cantab', 'name': 'Jupiter ACE', 'cpu': 'Z80', 'year': '1982'}
# {'country': 'Sweden', 'manufacturer': 'Luxor', 'name': 'ABC 80', 'cpu': 'Z80', 'year': '1978'}
# {'country': 'USA', 'manufacturer': 'Mattel', 'name': 'Aquarius', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'France', 'manufacturer': 'Matra', 'name': 'Matra Alice', 'cpu': '6803', 'year': '1983'}
# {'country': 'UK', 'manufacturer': 'Memotech', 'name': 'MTX500', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'UK', 'manufacturer': 'Memotech', 'name': 'MTX512', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'UK', 'manufacturer': 'Memotech', 'name': 'RS128', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'Australia', 'manufacturer': 'Microbee Systems', 'name': 'MicroBee', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'Brazil', 'manufacturer': 'Comércio de Componentes Eletrônicos', 'name': 'CCE MC-1000', 'cpu': 'Z80', 'year': '1985'}
# {'country': 'Brazil', 'manufacturer': 'Microdigital Eletronica', 'name': 'TK82C', 'cpu': 'Z80', 'year': '1985'}
# {'country': 'UK', 'manufacturer': 'Miles Gordon Technology', 'name': 'SAM Coupé', 'cpu': 'Z80', 'year': '1989'}
# {'country': 'Taiwan', 'manufacturer': 'Multitech', 'name': 'Microprofessor III', 'cpu': '6502', 'year': '1983'}
# {'country': 'Japan', 'manufacturer': 'NEC', 'name': 'NEC PC-100', 'cpu': '8086', 'year': '1983'}
# {'country': 'Japan', 'manufacturer': 'NEC Home Electronics', 'name': 'PC-6000', 'cpu': 'Z80', 'year': '1981'}
# {'country': 'Japan', 'manufacturer': 'NEC', 'name': 'PC-8800', 'cpu': 'Z80', 'year': '1981'}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 Color Computer', 'cpu': '6809', 'year': '1980'}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 Color Computer 2', 'cpu': '6809', 'year': '1980'}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 Color Computer 3', 'cpu': '6809', 'year': '1980'}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 Model I', 'cpu': 'Z80', 'year': '1977'}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 MC-10', 'cpu': '6803', 'year': '1983'}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'Tandy 1000', 'cpu': '8088', 'year': '1987'}
# {'country': 'Germany', 'manufacturer': 'Schneider Computer Division', 'name': 'Euro PC', 'cpu': '8088', 'year': '1988'}
# {'country': 'UK', 'manufacturer': 'Tangerine Computer Systems', 'name': 'Oric 1', 'cpu': '6502', 'year': '1983'}
# {'country': 'UK', 'manufacturer': 'Tangerine Computer Systems', 'name': 'Oric Atmos', 'cpu': '6502', 'year': '1984'}
# {'country': 'UK', 'manufacturer': 'Tangerine Computer Systems', 'name': 'Oric Telestrat', 'cpu': '6502', 'year': '1986'}
# {'country': 'Croatia', 'manufacturer': 'PEL Varaždin', 'name': 'Galeb', 'cpu': '6502', 'year': '1981'}
# {'country': 'Croatia', 'manufacturer': 'PEL Varaždin', 'name': 'Orao', 'cpu': '6502', 'year': '1984'}
# {'country': 'Netherlands', 'manufacturer': 'Philips', 'name': 'P2000', 'cpu': 'Z80', 'year': '1980'}
# {'country': 'Netherlands', 'manufacturer': 'Philips', 'name': 'G7480', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'Netherlands', 'manufacturer': 'Philips', 'name': 'Philips :YES', 'cpu': '80186', 'year': '1985'}
# {'country': 'Bulgaria', 'manufacturer': 'Pravetz', 'name': 'Pravetz 8', 'cpu': 'CM630 (6502 clone)', 'year': '1985'}
# {'country': 'Bulgaria', 'manufacturer': 'Pravetz', 'name': 'Pravetz 8D', 'cpu': '6502', 'year': '1982'}
# {'country': 'Bulgaria', 'manufacturer': 'Pravetz', 'name': 'IMKO-1', 'cpu': '6502', 'year': '1980'}
# {'country': 'New Zealand', 'manufacturer': 'Progeni Systems / Polycorp', 'name': 'Poly-1', 'cpu': '6809', 'year': '1981'}
# {'country': 'Brazil', 'manufacturer': 'Prológica', 'name': 'Prológica CP-400', 'cpu': '6809', 'year': '1984'}
# {'country': 'East Germany', 'manufacturer': 'VEB Robotron', 'name': 'KC 85', 'cpu': 'Z80 compatible', 'year': '1984'}
# {'country': 'East Germany', 'manufacturer': 'VEB Robotron', 'name': 'KC 87', 'cpu': 'Z80 compatible', 'year': '1987'}
# {'country': 'East Germany', 'manufacturer': 'VEB Robotron', 'name': 'Z1013', 'cpu': 'Z80 compatible', 'year': '1985'}
# {'country': 'Japan', 'manufacturer': 'Sega', 'name': 'SC-3000', 'cpu': 'Z80 compatible', 'year': '1983'}
# {'country': 'Japan', 'manufacturer': 'Sharp', 'name': 'MZ', 'cpu': 'Z80 compatible', 'year': '1979'}
# {'country': 'Japan', 'manufacturer': 'Sharp', 'name': 'Sharp X1', 'cpu': 'Z80 compatible', 'year': '1982'}
# {'country': 'Japan', 'manufacturer': 'Sharp', 'name': 'Sharp X68000', 'cpu': '68000', 'year': '1987'}
# {'country': 'UK', 'manufacturer': 'Sinclair Research', 'name': 'ZX80', 'cpu': 'Z80', 'year': '1980'}
# {'country': 'UK', 'manufacturer': 'Sinclair Research', 'name': 'ZX81', 'cpu': 'Z80', 'year': '1981'}
# {'country': 'UK', 'manufacturer': 'Sinclair Research', 'name': 'ZX Spectrum', 'cpu': 'Z80', 'year': '1982'}
# {'country': 'UK', 'manufacturer': 'Sinclair Research', 'name': 'Sinclair QL', 'cpu': '68008', 'year': '1984'}
# {'country': 'Japan', 'manufacturer': 'Sord Computer Corporation', 'name': 'Sord M200 Smart Home Computer', 'cpu': 'Z80', 'year': '1977'}
# {'country': 'Japan', 'manufacturer': 'Sord Computer Corporation', 'name': 'Sord M5', 'cpu': 'Z80', 'year': '1982'}
# {'country': 'New Zealand', 'manufacturer': 'Technosys', 'name': 'Aamber Pegasus', 'cpu': '6809', 'year': '1984'}
# {'country': 'USA', 'manufacturer': 'Texas Instruments', 'name': 'TI-99/4', 'cpu': 'TMS 9900', 'year': '1979'}
# {'country': 'USA', 'manufacturer': 'Texas Instruments', 'name': 'TI-99/4A', 'cpu': 'TMS 9900', 'year': '1979'}
# {'country': 'Czechoslovakia', 'manufacturer': 'Tesla', 'name': 'PMD 85', 'cpu': '8080', 'year': '1985'}
# {'country': 'Czechoslovakia', 'manufacturer': 'Štátny majetok Závadka š.p.', 'name': 'MAŤO', 'cpu': '8080', 'year': '1989'}
# {'country': 'France', 'manufacturer': 'Thomson', 'name': 'TO7', 'cpu': '6809', 'year': '1982'}
# {'country': 'France', 'manufacturer': 'Thomson', 'name': 'MO5', 'cpu': '6809', 'year': '1984'}
# {'country': 'USA/UK/Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Sinclair 1000', 'cpu': 'Z80', 'year': '1982'}
# {'country': 'USA/UK/Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Sinclair 1500', 'cpu': 'Z80', 'year': '1982'}
# {'country': 'USA/UK/Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Sinclair 2048', 'cpu': 'Z80', 'year': '1984'}
# {'country': 'Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Computer 2048', 'cpu': 'Z80', 'year': '1984'}
# {'country': 'USA/UK/Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Computer 2068', 'cpu': 'Z80', 'year': '1983'}
# {'country': 'Portugal/Poland', 'manufacturer': 'Timex Sinclair', 'name': 'Komputer 2086', 'cpu': 'Z80', 'year': '1986'}
# {'country': 'Japan', 'manufacturer': 'Tomy', 'name': 'Tomy Tutor', 'cpu': 'TMS 9900', 'year': '1986'}
# {'country': 'USSR', 'manufacturer': 'Vector', 'name': 'Vector-06C', 'cpu': '8080 compatible', 'year': '1987'}
# {'country': 'USA', 'manufacturer': 'Videobrain', 'name': 'VideoBrain Family Computer', 'cpu': 'Fairchild F8', 'year': '1977'}
# {'country': 'Hungary', 'manufacturer': 'Videoton', 'name': 'TVC', 'cpu': 'Z80', 'year': '1986'}
# {'country': 'Norway', 'manufacturer': 'West Computer AS', 'name': 'West PC-800', 'cpu': '6502, Z80', 'year': '1984'}
# {'country': 'Belgium', 'manufacturer': 'GEM', 'name': 'GEM 1000', 'cpu': 'Z80', 'year': '1985'}

# %%
import csv

with open('products.csv') as f:
    reader = csv.DictReader(f)
    for row in reader:
        row['year'] = int(row['year'])
        print(row)
# Out:
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'Acorn Atom', 'cpu': '6502', 'year': 1980}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'BBC Micro', 'cpu': '6502', 'year': 1981}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'Electron', 'cpu': '6502', 'year': 1983}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'BBC Master', 'cpu': '65SC12', 'year': 1986}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'Acorn Archimedes', 'cpu': 'ARM RISC', 'year': 1987}
# {'country': 'UK', 'manufacturer': 'Acorn Computers Ltd', 'name': 'A7000', 'cpu': 'ARM RISC', 'year': 1995}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'CPC 464', 'cpu': 'Z80', 'year': 1984}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'CPC 664', 'cpu': 'Z80', 'year': 1984}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'CPC 6128', 'cpu': 'Z80', 'year': 1984}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': '464 Plus', 'cpu': 'Z80', 'year': 1990}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': '6128 Plus', 'cpu': 'Z80', 'year': 1990}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'PCW', 'cpu': 'Z80', 'year': 1985}
# {'country': 'UK', 'manufacturer': 'Amstrad', 'name': 'PC-1512', 'cpu': '8086', 'year': 1986}
# {'country': 'China', 'manufacturer': 'Tsinghua University', 'name': 'CEC-I Zhonghua', 'cpu': '6502', 'year': 1986}
# {'country': 'USA', 'manufacturer': 'APF Electronics, Inc.', 'name': 'Imagination Machine', 'cpu': '6800', 'year': 1979}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple II', 'cpu': '6502', 'year': 1977}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple IIe', 'cpu': '6502', 'year': 1983}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple IIc', 'cpu': '65C02', 'year': 1984}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple IIc Plus', 'cpu': '65C02', 'year': 1988}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple II Plus', 'cpu': '6502', 'year': 1979}
# {'country': 'USA', 'manufacturer': 'Apple Computer', 'name': 'Apple IIGS', 'cpu': '65C816', 'year': 1986}
# {'country': 'UK', 'manufacturer': 'Apricot Computers', 'name': 'Apricot F1', 'cpu': '8088', 'year': 1984}
# {'country': 'Netherlands', 'manufacturer': 'Aster Computers', 'name': 'CT-80', 'cpu': 'Z80', 'year': 1982}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 400', 'cpu': '6502', 'year': 1979}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 800', 'cpu': '6502', 'year': 1979}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 1200XL', 'cpu': '6502', 'year': 1983}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 600XL', 'cpu': '6502', 'year': 1983}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 800XL', 'cpu': '6502', 'year': 1983}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 65XE', 'cpu': '6502C', 'year': 1985}
# {'country': 'USA', 'manufacturer': 'Atari, Inc.', 'name': 'Atari 130XE', 'cpu': '6502C', 'year': 1985}
# {'country': 'USA', 'manufacturer': 'Atari Corporation', 'name': 'Atari ST', 'cpu': '68000', 'year': 1985}
# {'country': 'USA', 'manufacturer': 'Atari Corporation', 'name': 'Atari TT', 'cpu': '68030', 'year': 1990}
# {'country': 'USA', 'manufacturer': 'Atari Corporation', 'name': 'Falcon', 'cpu': '68030 + 56001', 'year': 1992}
# {'country': 'USA', 'manufacturer': 'Bally Consumer Products', 'name': 'Bally Brain', 'cpu': 'Z80', 'year': 1979}
# {'country': 'USA', 'manufacturer': 'Bally Consumer Products', 'name': 'Bally Astrocade', 'cpu': 'Z80', 'year': 1977}
# {'country': 'Romania', 'manufacturer': 'Brasov Computer', 'name': 'CoBra', 'cpu': 'Z80', 'year': 1986}
# {'country': 'UK', 'manufacturer': 'Camputers', 'name': 'Lynx', 'cpu': 'Z80', 'year': 1983}
# {'country': 'USA', 'manufacturer': 'Coleco', 'name': 'Coleco Adam', 'cpu': 'Z80', 'year': 1983}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'PET', 'cpu': '6502', 'year': 1977}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'VIC-20', 'cpu': '6502', 'year': 1980}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore 64', 'cpu': '6510', 'year': 1982}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore Executive 64', 'cpu': '6510', 'year': 1982}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'MAX Machine', 'cpu': '6510', 'year': 1982}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore 16', 'cpu': '8501 (6502)', 'year': 1984}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore 116', 'cpu': '8501 (6502)', 'year': 1984}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Plus/4', 'cpu': '8501 (6502)', 'year': 1984}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Commodore 128', 'cpu': '8502 (6502) / Z80', 'year': 1985}
# {'country': 'USA', 'manufacturer': 'Commodore', 'name': 'Amiga', 'cpu': '68000 (family)', 'year': 1985}
# {'country': 'Hong Kong', 'manufacturer': 'Comx World Operations', 'name': 'Comx-35', 'cpu': 'RCA 1802', 'year': 1983}
# {'country': 'Belgium', 'manufacturer': 'Data Applications International', 'name': 'DAI Personal Computer', 'cpu': '8080', 'year': 1980}
# {'country': 'Hong Kong', 'manufacturer': 'Vtech', 'name': 'VTech Laser 200', 'cpu': 'Z80', 'year': 1985}
# {'country': 'Hong Kong', 'manufacturer': 'EACA', 'name': 'Video Genie', 'cpu': 'Z80', 'year': 1980}
# {'country': 'Hong Kong', 'manufacturer': 'EACA', 'name': 'Colour Genie', 'cpu': 'Z80', 'year': 1983}
# {'country': 'Hong Kong', 'manufacturer': 'Rabbit', 'name': 'Rabbit RX83', 'cpu': 'Z80', 'year': 1983}
# {'country': 'Czechoslovakia', 'manufacturer': 'Didaktik', 'name': 'Alpha', 'cpu': 'Z80', 'year': 1986}
# {'country': 'Czechoslovakia', 'manufacturer': 'Didaktik', 'name': 'Beta', 'cpu': 'Z80', 'year': 1986}
# {'country': 'Czechoslovakia', 'manufacturer': 'Didaktik', 'name': 'Gama', 'cpu': 'Z80', 'year': 1987}
# {'country': 'UK', 'manufacturer': 'Dragon Data', 'name': 'Dragon 32', 'cpu': '6809', 'year': 1982}
# {'country': 'UK', 'manufacturer': 'Dragon Data', 'name': 'Dragon 64', 'cpu': '6809', 'year': 1982}
# {'country': 'USSR', 'manufacturer': 'Dubna', 'name': 'Dubna 48K', 'cpu': 'Z80 (compatible)', 'year': 1991}
# {'country': 'USSR', 'manufacturer': 'Elektronika', 'name': 'BK-0010', 'cpu': 'PDP 11 (compatible)', 'year': 1985}
# {'country': 'USSR', 'manufacturer': 'AGAT', 'name': 'AGAT-9', 'cpu': 'Native/Apple II compatible', 'year': 1984}
# {'country': 'Serbia', 'manufacturer': 'Elektronska Industrija Niš', 'name': 'Pecom 32', 'cpu': 'RCA 1802', 'year': 1985}
# {'country': 'Serbia', 'manufacturer': 'Elektronska Industrija Niš', 'name': 'Pecom 64', 'cpu': 'RCA 1802', 'year': 1985}
# {'country': 'USA', 'manufacturer': 'Exidy', 'name': 'Exidy Sorcerer', 'cpu': 'Z80', 'year': 1978}
# {'country': 'UK', 'manufacturer': 'Intelligent Software', 'name': 'Enterprise 64', 'cpu': 'Z80', 'year': 1985}
# {'country': 'UK', 'manufacturer': 'Intelligent Software', 'name': 'Enterprise 128', 'cpu': 'Z80', 'year': 1985}
# {'country': 'Hong Kong', 'manufacturer': 'Lambda Electronics', 'name': 'Lambda 8300', 'cpu': 'Z80', 'year': 1985}
# {'country': 'USA', 'manufacturer': 'Franklin Computer Corporation', 'name': 'Franklin ACE', 'cpu': '6502', 'year': 1982}
# {'country': 'Japan', 'manufacturer': 'Fujitsu', 'name': 'FM Towns', 'cpu': '80386SX', 'year': 1989}
# {'country': 'Japan', 'manufacturer': 'Fujitsu', 'name': 'FM-7', 'cpu': '6809', 'year': 1982}
# {'country': 'UK', 'manufacturer': 'Grundy Business Systems', 'name': 'Grundy NewBrain', 'cpu': 'Z80', 'year': 1982}
# {'country': 'Brazil', 'manufacturer': 'Gradiente', 'name': 'Gradiente Expert', 'cpu': 'Z80', 'year': 1985}
# {'country': 'USA', 'manufacturer': 'Honeywell', 'name': 'Honeywell 316', 'cpu': 'DDP 16 Minicomputer', 'year': 1969}
# {'country': 'USA', 'manufacturer': 'IBM', 'name': 'PCjr', 'cpu': '8088', 'year': 1984}
# {'country': 'USA', 'manufacturer': 'IBM', 'name': 'IBM PS/1', 'cpu': '8088', 'year': 1990}
# {'country': 'USA', 'manufacturer': 'Interact', 'name': 'Interact Home Computer', 'cpu': '8080', 'year': 1979}
# {'country': 'USA', 'manufacturer': 'Intelligent Systems Corporation', 'name': 'Compucolor II', 'cpu': '8080', 'year': 1977}
# {'country': 'USSR', 'manufacturer': 'Intercompex', 'name': 'Hobbit', 'cpu': 'Z80 compatible', 'year': 1990}
# {'country': 'USSR', 'manufacturer': 'Iskra', 'name': 'Iskra-1030', 'cpu': '8086 compatible', 'year': 1989}
# {'country': 'Croatia', 'manufacturer': 'Ivasim', 'name': 'Ivel Ultra', 'cpu': '6502 compatible', 'year': 1984}
# {'country': 'Croatia', 'manufacturer': 'Ivasim', 'name': 'Ivel Z3', 'cpu': '6502 compatible', 'year': 1983}
# {'country': 'UK', 'manufacturer': 'Jupiter Cantab', 'name': 'Jupiter ACE', 'cpu': 'Z80', 'year': 1982}
# {'country': 'Sweden', 'manufacturer': 'Luxor', 'name': 'ABC 80', 'cpu': 'Z80', 'year': 1978}
# {'country': 'USA', 'manufacturer': 'Mattel', 'name': 'Aquarius', 'cpu': 'Z80', 'year': 1983}
# {'country': 'France', 'manufacturer': 'Matra', 'name': 'Matra Alice', 'cpu': '6803', 'year': 1983}
# {'country': 'UK', 'manufacturer': 'Memotech', 'name': 'MTX500', 'cpu': 'Z80', 'year': 1983}
# {'country': 'UK', 'manufacturer': 'Memotech', 'name': 'MTX512', 'cpu': 'Z80', 'year': 1983}
# {'country': 'UK', 'manufacturer': 'Memotech', 'name': 'RS128', 'cpu': 'Z80', 'year': 1983}
# {'country': 'Australia', 'manufacturer': 'Microbee Systems', 'name': 'MicroBee', 'cpu': 'Z80', 'year': 1983}
# {'country': 'Brazil', 'manufacturer': 'Comércio de Componentes Eletrônicos', 'name': 'CCE MC-1000', 'cpu': 'Z80', 'year': 1985}
# {'country': 'Brazil', 'manufacturer': 'Microdigital Eletronica', 'name': 'TK82C', 'cpu': 'Z80', 'year': 1985}
# {'country': 'UK', 'manufacturer': 'Miles Gordon Technology', 'name': 'SAM Coupé', 'cpu': 'Z80', 'year': 1989}
# {'country': 'Taiwan', 'manufacturer': 'Multitech', 'name': 'Microprofessor III', 'cpu': '6502', 'year': 1983}
# {'country': 'Japan', 'manufacturer': 'NEC', 'name': 'NEC PC-100', 'cpu': '8086', 'year': 1983}
# {'country': 'Japan', 'manufacturer': 'NEC Home Electronics', 'name': 'PC-6000', 'cpu': 'Z80', 'year': 1981}
# {'country': 'Japan', 'manufacturer': 'NEC', 'name': 'PC-8800', 'cpu': 'Z80', 'year': 1981}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 Color Computer', 'cpu': '6809', 'year': 1980}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 Color Computer 2', 'cpu': '6809', 'year': 1980}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 Color Computer 3', 'cpu': '6809', 'year': 1980}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 Model I', 'cpu': 'Z80', 'year': 1977}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'TRS-80 MC-10', 'cpu': '6803', 'year': 1983}
# {'country': 'USA', 'manufacturer': 'Radio Shack', 'name': 'Tandy 1000', 'cpu': '8088', 'year': 1987}
# {'country': 'Germany', 'manufacturer': 'Schneider Computer Division', 'name': 'Euro PC', 'cpu': '8088', 'year': 1988}
# {'country': 'UK', 'manufacturer': 'Tangerine Computer Systems', 'name': 'Oric 1', 'cpu': '6502', 'year': 1983}
# {'country': 'UK', 'manufacturer': 'Tangerine Computer Systems', 'name': 'Oric Atmos', 'cpu': '6502', 'year': 1984}
# {'country': 'UK', 'manufacturer': 'Tangerine Computer Systems', 'name': 'Oric Telestrat', 'cpu': '6502', 'year': 1986}
# {'country': 'Croatia', 'manufacturer': 'PEL Varaždin', 'name': 'Galeb', 'cpu': '6502', 'year': 1981}
# {'country': 'Croatia', 'manufacturer': 'PEL Varaždin', 'name': 'Orao', 'cpu': '6502', 'year': 1984}
# {'country': 'Netherlands', 'manufacturer': 'Philips', 'name': 'P2000', 'cpu': 'Z80', 'year': 1980}
# {'country': 'Netherlands', 'manufacturer': 'Philips', 'name': 'G7480', 'cpu': 'Z80', 'year': 1983}
# {'country': 'Netherlands', 'manufacturer': 'Philips', 'name': 'Philips :YES', 'cpu': '80186', 'year': 1985}
# {'country': 'Bulgaria', 'manufacturer': 'Pravetz', 'name': 'Pravetz 8', 'cpu': 'CM630 (6502 clone)', 'year': 1985}
# {'country': 'Bulgaria', 'manufacturer': 'Pravetz', 'name': 'Pravetz 8D', 'cpu': '6502', 'year': 1982}
# {'country': 'Bulgaria', 'manufacturer': 'Pravetz', 'name': 'IMKO-1', 'cpu': '6502', 'year': 1980}
# {'country': 'New Zealand', 'manufacturer': 'Progeni Systems / Polycorp', 'name': 'Poly-1', 'cpu': '6809', 'year': 1981}
# {'country': 'Brazil', 'manufacturer': 'Prológica', 'name': 'Prológica CP-400', 'cpu': '6809', 'year': 1984}
# {'country': 'East Germany', 'manufacturer': 'VEB Robotron', 'name': 'KC 85', 'cpu': 'Z80 compatible', 'year': 1984}
# {'country': 'East Germany', 'manufacturer': 'VEB Robotron', 'name': 'KC 87', 'cpu': 'Z80 compatible', 'year': 1987}
# {'country': 'East Germany', 'manufacturer': 'VEB Robotron', 'name': 'Z1013', 'cpu': 'Z80 compatible', 'year': 1985}
# {'country': 'Japan', 'manufacturer': 'Sega', 'name': 'SC-3000', 'cpu': 'Z80 compatible', 'year': 1983}
# {'country': 'Japan', 'manufacturer': 'Sharp', 'name': 'MZ', 'cpu': 'Z80 compatible', 'year': 1979}
# {'country': 'Japan', 'manufacturer': 'Sharp', 'name': 'Sharp X1', 'cpu': 'Z80 compatible', 'year': 1982}
# {'country': 'Japan', 'manufacturer': 'Sharp', 'name': 'Sharp X68000', 'cpu': '68000', 'year': 1987}
# {'country': 'UK', 'manufacturer': 'Sinclair Research', 'name': 'ZX80', 'cpu': 'Z80', 'year': 1980}
# {'country': 'UK', 'manufacturer': 'Sinclair Research', 'name': 'ZX81', 'cpu': 'Z80', 'year': 1981}
# {'country': 'UK', 'manufacturer': 'Sinclair Research', 'name': 'ZX Spectrum', 'cpu': 'Z80', 'year': 1982}
# {'country': 'UK', 'manufacturer': 'Sinclair Research', 'name': 'Sinclair QL', 'cpu': '68008', 'year': 1984}
# {'country': 'Japan', 'manufacturer': 'Sord Computer Corporation', 'name': 'Sord M200 Smart Home Computer', 'cpu': 'Z80', 'year': 1977}
# {'country': 'Japan', 'manufacturer': 'Sord Computer Corporation', 'name': 'Sord M5', 'cpu': 'Z80', 'year': 1982}
# {'country': 'New Zealand', 'manufacturer': 'Technosys', 'name': 'Aamber Pegasus', 'cpu': '6809', 'year': 1984}
# {'country': 'USA', 'manufacturer': 'Texas Instruments', 'name': 'TI-99/4', 'cpu': 'TMS 9900', 'year': 1979}
# {'country': 'USA', 'manufacturer': 'Texas Instruments', 'name': 'TI-99/4A', 'cpu': 'TMS 9900', 'year': 1979}
# {'country': 'Czechoslovakia', 'manufacturer': 'Tesla', 'name': 'PMD 85', 'cpu': '8080', 'year': 1985}
# {'country': 'Czechoslovakia', 'manufacturer': 'Štátny majetok Závadka š.p.', 'name': 'MAŤO', 'cpu': '8080', 'year': 1989}
# {'country': 'France', 'manufacturer': 'Thomson', 'name': 'TO7', 'cpu': '6809', 'year': 1982}
# {'country': 'France', 'manufacturer': 'Thomson', 'name': 'MO5', 'cpu': '6809', 'year': 1984}
# {'country': 'USA/UK/Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Sinclair 1000', 'cpu': 'Z80', 'year': 1982}
# {'country': 'USA/UK/Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Sinclair 1500', 'cpu': 'Z80', 'year': 1982}
# {'country': 'USA/UK/Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Sinclair 2048', 'cpu': 'Z80', 'year': 1984}
# {'country': 'Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Computer 2048', 'cpu': 'Z80', 'year': 1984}
# {'country': 'USA/UK/Portugal', 'manufacturer': 'Timex Sinclair', 'name': 'Timex Computer 2068', 'cpu': 'Z80', 'year': 1983}
# {'country': 'Portugal/Poland', 'manufacturer': 'Timex Sinclair', 'name': 'Komputer 2086', 'cpu': 'Z80', 'year': 1986}
# {'country': 'Japan', 'manufacturer': 'Tomy', 'name': 'Tomy Tutor', 'cpu': 'TMS 9900', 'year': 1986}
# {'country': 'USSR', 'manufacturer': 'Vector', 'name': 'Vector-06C', 'cpu': '8080 compatible', 'year': 1987}
# {'country': 'USA', 'manufacturer': 'Videobrain', 'name': 'VideoBrain Family Computer', 'cpu': 'Fairchild F8', 'year': 1977}
# {'country': 'Hungary', 'manufacturer': 'Videoton', 'name': 'TVC', 'cpu': 'Z80', 'year': 1986}
# {'country': 'Norway', 'manufacturer': 'West Computer AS', 'name': 'West PC-800', 'cpu': '6502, Z80', 'year': 1984}
# {'country': 'Belgium', 'manufacturer': 'GEM', 'name': 'GEM 1000', 'cpu': 'Z80', 'year': 1985}

# %% [markdown]
# ```
# Option 1: sqlite3 CLI (simplest, already installed)
#
#   sqlite3 chapter2/retrofun.sqlite
#
#   Then at the sqlite prompt:
#   .tables                     -- list all tables
#   .schema products            -- show table structure
#   SELECT * FROM products;     -- view all data
#   .quit                       -- exit
# ```

# %% [markdown]
# # Queries

# %%
from db import Session
from models import Product

# %%
session = Session()

# %% [markdown]
# This is a different way of creating a session that does not use a context manager. The context manager approach to sessions is very convenient in an application, but it gets in the way when working interactively in the Python prompt, so a direct creation is better in this context.
#
# # Query definition
#
# Relational databases use the SELECT keyword to implement queries. SQLAlchemy provides a select() function with similar functionality. The simplest query is the one that returns all the elements in a table. Here is how to define a query that retrieves all the products stored in the database:

# %%
from sqlalchemy import select
q = select(Product)

# %%
print(q)
# Out:
# SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products

# %%
r = session.execute(q)
list(r)
# Out:
# [(Product(1, "Acorn Atom", "Acorn Computers Ltd", 1980, "UK", "6502"),),
#  (Product(2, "BBC Micro", "Acorn Computers Ltd", 1981, "UK", "6502"),),
#  (Product(3, "Electron", "Acorn Computers Ltd", 1983, "UK", "6502"),),
#  (Product(4, "BBC Master", "Acorn Computers Ltd", 1986, "UK", "65SC12"),),
#  (Product(5, "Acorn Archimedes", "Acorn Computers Ltd", 1987, "UK", "ARM RISC"),),
#  (Product(6, "A7000", "Acorn Computers Ltd", 1995, "UK", "ARM RISC"),),
#  (Product(7, "CPC 464", "Amstrad", 1984, "UK", "Z80"),),
#  (Product(8, "CPC 664", "Amstrad", 1984, "UK", "Z80"),),
#  (Product(9, "CPC 6128", "Amstrad", 1984, "UK", "Z80"),),
#  (Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),),
#  (Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),),
#  (Product(12, "PCW", "Amstrad", 1985, "UK", "Z80"),),
#  (Product(13, "PC-1512", "Amstrad", 1986, "UK", "8086"),),
#  (Product(14, "CEC-I Zhonghua", "Tsinghua University", 1986, "China", "6502"),),
#  (Product(15, "Imagination Machine", "APF Electronics, Inc.", 1979, "USA", "6800"),),
#  (Product(16, "Apple II", "Apple Computer", 1977, "USA", "6502"),),
#  (Product(17, "Apple IIe", "Apple Computer", 1983, "USA", "6502"),),
#  (Product(18, "Apple IIc", "Apple Computer", 1984, "USA", "65C02"),),
#  (Product(19, "Apple IIc Plus", "Apple Computer", 1988, "USA", "65C02"),),
#  (Product(20, "Apple II Plus", "Apple Computer", 1979, "USA", "6502"),),
#  (Product(21, "Apple IIGS", "Apple Computer", 1986, "USA", "65C816"),),
#  (Product(22, "Apricot F1", "Apricot Computers", 1984, "UK", "8088"),),
#  (Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80"),),
#  (Product(24, "Atari 400", "Atari, Inc.", 1979, "USA", "6502"),),
#  (Product(25, "Atari 800", "Atari, Inc.", 1979, "USA", "6502"),),
#  (Product(26, "Atari 1200XL", "Atari, Inc.", 1983, "USA", "6502"),),
#  (Product(27, "Atari 600XL", "Atari, Inc.", 1983, "USA", "6502"),),
#  (Product(28, "Atari 800XL", "Atari, Inc.", 1983, "USA", "6502"),),
#  (Product(29, "Atari 65XE", "Atari, Inc.", 1985, "USA", "6502C"),),
#  (Product(30, "Atari 130XE", "Atari, Inc.", 1985, "USA", "6502C"),),
#  (Product(31, "Atari ST", "Atari Corporation", 1985, "USA", "68000"),),
#  (Product(32, "Atari TT", "Atari Corporation", 1990, "USA", "68030"),),
#  (Product(33, "Falcon", "Atari Corporation", 1992, "USA", "68030 + 56001"),),
#  (Product(34, "Bally Brain", "Bally Consumer Products", 1979, "USA", "Z80"),),
#  (Product(35, "Bally Astrocade", "Bally Consumer Products", 1977, "USA", "Z80"),),
#  (Product(36, "CoBra", "Brasov Computer", 1986, "Romania", "Z80"),),
#  (Product(37, "Lynx", "Camputers", 1983, "UK", "Z80"),),
#  (Product(38, "Coleco Adam", "Coleco", 1983, "USA", "Z80"),),
#  (Product(39, "PET", "Commodore", 1977, "USA", "6502"),),
#  (Product(40, "VIC-20", "Commodore", 1980, "USA", "6502"),),
#  (Product(41, "Commodore 64", "Commodore", 1982, "USA", "6510"),),
#  (Product(42, "Commodore Executive 64", "Commodore", 1982, "USA", "6510"),),
#  (Product(43, "MAX Machine", "Commodore", 1982, "USA", "6510"),),
#  (Product(44, "Commodore 16", "Commodore", 1984, "USA", "8501 (6502)"),),
#  (Product(45, "Commodore 116", "Commodore", 1984, "USA", "8501 (6502)"),),
#  (Product(46, "Plus/4", "Commodore", 1984, "USA", "8501 (6502)"),),
#  (Product(47, "Commodore 128", "Commodore", 1985, "USA", "8502 (6502) / Z80"),),
#  (Product(48, "Amiga", "Commodore", 1985, "USA", "68000 (family)"),),
#  (Product(49, "Comx-35", "Comx World Operations", 1983, "Hong Kong", "RCA 1802"),),
#  (Product(50, "DAI Personal Computer", "Data Applications International", 1980, "Belgium", "8080"),),
#  (Product(51, "VTech Laser 200", "Vtech", 1985, "Hong Kong", "Z80"),),
#  (Product(52, "Video Genie", "EACA", 1980, "Hong Kong", "Z80"),),
#  (Product(53, "Colour Genie", "EACA", 1983, "Hong Kong", "Z80"),),
#  (Product(54, "Rabbit RX83", "Rabbit", 1983, "Hong Kong", "Z80"),),
#  (Product(55, "Alpha", "Didaktik", 1986, "Czechoslovakia", "Z80"),),
#  (Product(56, "Beta", "Didaktik", 1986, "Czechoslovakia", "Z80"),),
#  (Product(57, "Gama", "Didaktik", 1987, "Czechoslovakia", "Z80"),),
#  (Product(58, "Dragon 32", "Dragon Data", 1982, "UK", "6809"),),
#  (Product(59, "Dragon 64", "Dragon Data", 1982, "UK", "6809"),),
#  (Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),),
#  (Product(61, "BK-0010", "Elektronika", 1985, "USSR", "PDP 11 (compatible)"),),
#  (Product(62, "AGAT-9", "AGAT", 1984, "USSR", "Native/Apple II compatible"),),
#  (Product(63, "Pecom 32", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),),
#  (Product(64, "Pecom 64", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),),
#  (Product(65, "Exidy Sorcerer", "Exidy", 1978, "USA", "Z80"),),
#  (Product(66, "Enterprise 64", "Intelligent Software", 1985, "UK", "Z80"),),
#  (Product(67, "Enterprise 128", "Intelligent Software", 1985, "UK", "Z80"),),
#  (Product(68, "Lambda 8300", "Lambda Electronics", 1985, "Hong Kong", "Z80"),),
#  (Product(69, "Franklin ACE", "Franklin Computer Corporation", 1982, "USA", "6502"),),
#  (Product(70, "FM Towns", "Fujitsu", 1989, "Japan", "80386SX"),),
#  (Product(71, "FM-7", "Fujitsu", 1982, "Japan", "6809"),),
#  (Product(72, "Grundy NewBrain", "Grundy Business Systems", 1982, "UK", "Z80"),),
#  (Product(73, "Gradiente Expert", "Gradiente", 1985, "Brazil", "Z80"),),
#  (Product(74, "Honeywell 316", "Honeywell", 1969, "USA", "DDP 16 Minicomputer"),),
#  (Product(75, "PCjr", "IBM", 1984, "USA", "8088"),),
#  (Product(76, "IBM PS/1", "IBM", 1990, "USA", "8088"),),
#  (Product(77, "Interact Home Computer", "Interact", 1979, "USA", "8080"),),
#  (Product(78, "Compucolor II", "Intelligent Systems Corporation", 1977, "USA", "8080"),),
#  (Product(79, "Hobbit", "Intercompex", 1990, "USSR", "Z80 compatible"),),
#  (Product(80, "Iskra-1030", "Iskra", 1989, "USSR", "8086 compatible"),),
#  (Product(81, "Ivel Ultra", "Ivasim", 1984, "Croatia", "6502 compatible"),),
#  (Product(82, "Ivel Z3", "Ivasim", 1983, "Croatia", "6502 compatible"),),
#  (Product(83, "Jupiter ACE", "Jupiter Cantab", 1982, "UK", "Z80"),),
#  (Product(84, "ABC 80", "Luxor", 1978, "Sweden", "Z80"),),
#  (Product(85, "Aquarius", "Mattel", 1983, "USA", "Z80"),),
#  (Product(86, "Matra Alice", "Matra", 1983, "France", "6803"),),
#  (Product(87, "MTX500", "Memotech", 1983, "UK", "Z80"),),
#  (Product(88, "MTX512", "Memotech", 1983, "UK", "Z80"),),
#  (Product(89, "RS128", "Memotech", 1983, "UK", "Z80"),),
#  (Product(90, "MicroBee", "Microbee Systems", 1983, "Australia", "Z80"),),
#  (Product(91, "CCE MC-1000", "Comércio de Componentes Eletrônicos", 1985, "Brazil", "Z80"),),
#  (Product(92, "TK82C", "Microdigital Eletronica", 1985, "Brazil", "Z80"),),
#  (Product(93, "SAM Coupé", "Miles Gordon Technology", 1989, "UK", "Z80"),),
#  (Product(94, "Microprofessor III", "Multitech", 1983, "Taiwan", "6502"),),
#  (Product(95, "NEC PC-100", "NEC", 1983, "Japan", "8086"),),
#  (Product(96, "PC-6000", "NEC Home Electronics", 1981, "Japan", "Z80"),),
#  (Product(97, "PC-8800", "NEC", 1981, "Japan", "Z80"),),
#  (Product(98, "TRS-80 Color Computer", "Radio Shack", 1980, "USA", "6809"),),
#  (Product(99, "TRS-80 Color Computer 2", "Radio Shack", 1980, "USA", "6809"),),
#  (Product(100, "TRS-80 Color Computer 3", "Radio Shack", 1980, "USA", "6809"),),
#  (Product(101, "TRS-80 Model I", "Radio Shack", 1977, "USA", "Z80"),),
#  (Product(102, "TRS-80 MC-10", "Radio Shack", 1983, "USA", "6803"),),
#  (Product(103, "Tandy 1000", "Radio Shack", 1987, "USA", "8088"),),
#  (Product(104, "Euro PC", "Schneider Computer Division", 1988, "Germany", "8088"),),
#  (Product(105, "Oric 1", "Tangerine Computer Systems", 1983, "UK", "6502"),),
#  (Product(106, "Oric Atmos", "Tangerine Computer Systems", 1984, "UK", "6502"),),
#  (Product(107, "Oric Telestrat", "Tangerine Computer Systems", 1986, "UK", "6502"),),
#  (Product(108, "Galeb", "PEL Varaždin", 1981, "Croatia", "6502"),),
#  (Product(109, "Orao", "PEL Varaždin", 1984, "Croatia", "6502"),),
#  (Product(110, "P2000", "Philips", 1980, "Netherlands", "Z80"),),
#  (Product(111, "G7480", "Philips", 1983, "Netherlands", "Z80"),),
#  (Product(112, "Philips :YES", "Philips", 1985, "Netherlands", "80186"),),
#  (Product(113, "Pravetz 8", "Pravetz", 1985, "Bulgaria", "CM630 (6502 clone)"),),
#  (Product(114, "Pravetz 8D", "Pravetz", 1982, "Bulgaria", "6502"),),
#  (Product(115, "IMKO-1", "Pravetz", 1980, "Bulgaria", "6502"),),
#  (Product(116, "Poly-1", "Progeni Systems / Polycorp", 1981, "New Zealand", "6809"),),
#  (Product(117, "Prológica CP-400", "Prológica", 1984, "Brazil", "6809"),),
#  (Product(118, "KC 85", "VEB Robotron", 1984, "East Germany", "Z80 compatible"),),
#  (Product(119, "KC 87", "VEB Robotron", 1987, "East Germany", "Z80 compatible"),),
#  (Product(120, "Z1013", "VEB Robotron", 1985, "East Germany", "Z80 compatible"),),
#  (Product(121, "SC-3000", "Sega", 1983, "Japan", "Z80 compatible"),),
#  (Product(122, "MZ", "Sharp", 1979, "Japan", "Z80 compatible"),),
#  (Product(123, "Sharp X1", "Sharp", 1982, "Japan", "Z80 compatible"),),
#  (Product(124, "Sharp X68000", "Sharp", 1987, "Japan", "68000"),),
#  (Product(125, "ZX80", "Sinclair Research", 1980, "UK", "Z80"),),
#  (Product(126, "ZX81", "Sinclair Research", 1981, "UK", "Z80"),),
#  (Product(127, "ZX Spectrum", "Sinclair Research", 1982, "UK", "Z80"),),
#  (Product(128, "Sinclair QL", "Sinclair Research", 1984, "UK", "68008"),),
#  (Product(129, "Sord M200 Smart Home Computer", "Sord Computer Corporation", 1977, "Japan", "Z80"),),
#  (Product(130, "Sord M5", "Sord Computer Corporation", 1982, "Japan", "Z80"),),
#  (Product(131, "Aamber Pegasus", "Technosys", 1984, "New Zealand", "6809"),),
#  (Product(132, "TI-99/4", "Texas Instruments", 1979, "USA", "TMS 9900"),),
#  (Product(133, "TI-99/4A", "Texas Instruments", 1979, "USA", "TMS 9900"),),
#  (Product(134, "PMD 85", "Tesla", 1985, "Czechoslovakia", "8080"),),
#  (Product(135, "MAŤO", "Štátny majetok Závadka š.p.", 1989, "Czechoslovakia", "8080"),),
#  (Product(136, "TO7", "Thomson", 1982, "France", "6809"),),
#  (Product(137, "MO5", "Thomson", 1984, "France", "6809"),),
#  (Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),),
#  (Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),),
#  (Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80"),),
#  (Product(141, "Timex Computer 2048", "Timex Sinclair", 1984, "Portugal", "Z80"),),
#  (Product(142, "Timex Computer 2068", "Timex Sinclair", 1983, "USA/UK/Portugal", "Z80"),),
#  (Product(143, "Komputer 2086", "Timex Sinclair", 1986, "Portugal/Poland", "Z80"),),
#  (Product(144, "Tomy Tutor", "Tomy", 1986, "Japan", "TMS 9900"),),
#  (Product(145, "Vector-06C", "Vector", 1987, "USSR", "8080 compatible"),),
#  (Product(146, "VideoBrain Family Computer", "Videobrain", 1977, "USA", "Fairchild F8"),),
#  (Product(147, "TVC", "Videoton", 1986, "Hungary", "Z80"),),
#  (Product(148, "West PC-800", "West Computer AS", 1984, "Norway", "6502, Z80"),),
#  (Product(149, "GEM 1000", "GEM", 1985, "Belgium", "Z80"),)]

# %% [markdown]
# only showing the id and name beause of the __repr__ method in Product

# %% [markdown]
# The all() method on the results object returned by execute() achieves the same effect as teh conversion done by list()

# %%
session.execute(q).all()
# Out:
# [(Product(1, "Acorn Atom", "Acorn Computers Ltd", 1980, "UK", "6502"),),
#  (Product(2, "BBC Micro", "Acorn Computers Ltd", 1981, "UK", "6502"),),
#  (Product(3, "Electron", "Acorn Computers Ltd", 1983, "UK", "6502"),),
#  (Product(4, "BBC Master", "Acorn Computers Ltd", 1986, "UK", "65SC12"),),
#  (Product(5, "Acorn Archimedes", "Acorn Computers Ltd", 1987, "UK", "ARM RISC"),),
#  (Product(6, "A7000", "Acorn Computers Ltd", 1995, "UK", "ARM RISC"),),
#  (Product(7, "CPC 464", "Amstrad", 1984, "UK", "Z80"),),
#  (Product(8, "CPC 664", "Amstrad", 1984, "UK", "Z80"),),
#  (Product(9, "CPC 6128", "Amstrad", 1984, "UK", "Z80"),),
#  (Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),),
#  (Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),),
#  (Product(12, "PCW", "Amstrad", 1985, "UK", "Z80"),),
#  (Product(13, "PC-1512", "Amstrad", 1986, "UK", "8086"),),
#  (Product(14, "CEC-I Zhonghua", "Tsinghua University", 1986, "China", "6502"),),
#  (Product(15, "Imagination Machine", "APF Electronics, Inc.", 1979, "USA", "6800"),),
#  (Product(16, "Apple II", "Apple Computer", 1977, "USA", "6502"),),
#  (Product(17, "Apple IIe", "Apple Computer", 1983, "USA", "6502"),),
#  (Product(18, "Apple IIc", "Apple Computer", 1984, "USA", "65C02"),),
#  (Product(19, "Apple IIc Plus", "Apple Computer", 1988, "USA", "65C02"),),
#  (Product(20, "Apple II Plus", "Apple Computer", 1979, "USA", "6502"),),
#  (Product(21, "Apple IIGS", "Apple Computer", 1986, "USA", "65C816"),),
#  (Product(22, "Apricot F1", "Apricot Computers", 1984, "UK", "8088"),),
#  (Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80"),),
#  (Product(24, "Atari 400", "Atari, Inc.", 1979, "USA", "6502"),),
#  (Product(25, "Atari 800", "Atari, Inc.", 1979, "USA", "6502"),),
#  (Product(26, "Atari 1200XL", "Atari, Inc.", 1983, "USA", "6502"),),
#  (Product(27, "Atari 600XL", "Atari, Inc.", 1983, "USA", "6502"),),
#  (Product(28, "Atari 800XL", "Atari, Inc.", 1983, "USA", "6502"),),
#  (Product(29, "Atari 65XE", "Atari, Inc.", 1985, "USA", "6502C"),),
#  (Product(30, "Atari 130XE", "Atari, Inc.", 1985, "USA", "6502C"),),
#  (Product(31, "Atari ST", "Atari Corporation", 1985, "USA", "68000"),),
#  (Product(32, "Atari TT", "Atari Corporation", 1990, "USA", "68030"),),
#  (Product(33, "Falcon", "Atari Corporation", 1992, "USA", "68030 + 56001"),),
#  (Product(34, "Bally Brain", "Bally Consumer Products", 1979, "USA", "Z80"),),
#  (Product(35, "Bally Astrocade", "Bally Consumer Products", 1977, "USA", "Z80"),),
#  (Product(36, "CoBra", "Brasov Computer", 1986, "Romania", "Z80"),),
#  (Product(37, "Lynx", "Camputers", 1983, "UK", "Z80"),),
#  (Product(38, "Coleco Adam", "Coleco", 1983, "USA", "Z80"),),
#  (Product(39, "PET", "Commodore", 1977, "USA", "6502"),),
#  (Product(40, "VIC-20", "Commodore", 1980, "USA", "6502"),),
#  (Product(41, "Commodore 64", "Commodore", 1982, "USA", "6510"),),
#  (Product(42, "Commodore Executive 64", "Commodore", 1982, "USA", "6510"),),
#  (Product(43, "MAX Machine", "Commodore", 1982, "USA", "6510"),),
#  (Product(44, "Commodore 16", "Commodore", 1984, "USA", "8501 (6502)"),),
#  (Product(45, "Commodore 116", "Commodore", 1984, "USA", "8501 (6502)"),),
#  (Product(46, "Plus/4", "Commodore", 1984, "USA", "8501 (6502)"),),
#  (Product(47, "Commodore 128", "Commodore", 1985, "USA", "8502 (6502) / Z80"),),
#  (Product(48, "Amiga", "Commodore", 1985, "USA", "68000 (family)"),),
#  (Product(49, "Comx-35", "Comx World Operations", 1983, "Hong Kong", "RCA 1802"),),
#  (Product(50, "DAI Personal Computer", "Data Applications International", 1980, "Belgium", "8080"),),
#  (Product(51, "VTech Laser 200", "Vtech", 1985, "Hong Kong", "Z80"),),
#  (Product(52, "Video Genie", "EACA", 1980, "Hong Kong", "Z80"),),
#  (Product(53, "Colour Genie", "EACA", 1983, "Hong Kong", "Z80"),),
#  (Product(54, "Rabbit RX83", "Rabbit", 1983, "Hong Kong", "Z80"),),
#  (Product(55, "Alpha", "Didaktik", 1986, "Czechoslovakia", "Z80"),),
#  (Product(56, "Beta", "Didaktik", 1986, "Czechoslovakia", "Z80"),),
#  (Product(57, "Gama", "Didaktik", 1987, "Czechoslovakia", "Z80"),),
#  (Product(58, "Dragon 32", "Dragon Data", 1982, "UK", "6809"),),
#  (Product(59, "Dragon 64", "Dragon Data", 1982, "UK", "6809"),),
#  (Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),),
#  (Product(61, "BK-0010", "Elektronika", 1985, "USSR", "PDP 11 (compatible)"),),
#  (Product(62, "AGAT-9", "AGAT", 1984, "USSR", "Native/Apple II compatible"),),
#  (Product(63, "Pecom 32", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),),
#  (Product(64, "Pecom 64", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),),
#  (Product(65, "Exidy Sorcerer", "Exidy", 1978, "USA", "Z80"),),
#  (Product(66, "Enterprise 64", "Intelligent Software", 1985, "UK", "Z80"),),
#  (Product(67, "Enterprise 128", "Intelligent Software", 1985, "UK", "Z80"),),
#  (Product(68, "Lambda 8300", "Lambda Electronics", 1985, "Hong Kong", "Z80"),),
#  (Product(69, "Franklin ACE", "Franklin Computer Corporation", 1982, "USA", "6502"),),
#  (Product(70, "FM Towns", "Fujitsu", 1989, "Japan", "80386SX"),),
#  (Product(71, "FM-7", "Fujitsu", 1982, "Japan", "6809"),),
#  (Product(72, "Grundy NewBrain", "Grundy Business Systems", 1982, "UK", "Z80"),),
#  (Product(73, "Gradiente Expert", "Gradiente", 1985, "Brazil", "Z80"),),
#  (Product(74, "Honeywell 316", "Honeywell", 1969, "USA", "DDP 16 Minicomputer"),),
#  (Product(75, "PCjr", "IBM", 1984, "USA", "8088"),),
#  (Product(76, "IBM PS/1", "IBM", 1990, "USA", "8088"),),
#  (Product(77, "Interact Home Computer", "Interact", 1979, "USA", "8080"),),
#  (Product(78, "Compucolor II", "Intelligent Systems Corporation", 1977, "USA", "8080"),),
#  (Product(79, "Hobbit", "Intercompex", 1990, "USSR", "Z80 compatible"),),
#  (Product(80, "Iskra-1030", "Iskra", 1989, "USSR", "8086 compatible"),),
#  (Product(81, "Ivel Ultra", "Ivasim", 1984, "Croatia", "6502 compatible"),),
#  (Product(82, "Ivel Z3", "Ivasim", 1983, "Croatia", "6502 compatible"),),
#  (Product(83, "Jupiter ACE", "Jupiter Cantab", 1982, "UK", "Z80"),),
#  (Product(84, "ABC 80", "Luxor", 1978, "Sweden", "Z80"),),
#  (Product(85, "Aquarius", "Mattel", 1983, "USA", "Z80"),),
#  (Product(86, "Matra Alice", "Matra", 1983, "France", "6803"),),
#  (Product(87, "MTX500", "Memotech", 1983, "UK", "Z80"),),
#  (Product(88, "MTX512", "Memotech", 1983, "UK", "Z80"),),
#  (Product(89, "RS128", "Memotech", 1983, "UK", "Z80"),),
#  (Product(90, "MicroBee", "Microbee Systems", 1983, "Australia", "Z80"),),
#  (Product(91, "CCE MC-1000", "Comércio de Componentes Eletrônicos", 1985, "Brazil", "Z80"),),
#  (Product(92, "TK82C", "Microdigital Eletronica", 1985, "Brazil", "Z80"),),
#  (Product(93, "SAM Coupé", "Miles Gordon Technology", 1989, "UK", "Z80"),),
#  (Product(94, "Microprofessor III", "Multitech", 1983, "Taiwan", "6502"),),
#  (Product(95, "NEC PC-100", "NEC", 1983, "Japan", "8086"),),
#  (Product(96, "PC-6000", "NEC Home Electronics", 1981, "Japan", "Z80"),),
#  (Product(97, "PC-8800", "NEC", 1981, "Japan", "Z80"),),
#  (Product(98, "TRS-80 Color Computer", "Radio Shack", 1980, "USA", "6809"),),
#  (Product(99, "TRS-80 Color Computer 2", "Radio Shack", 1980, "USA", "6809"),),
#  (Product(100, "TRS-80 Color Computer 3", "Radio Shack", 1980, "USA", "6809"),),
#  (Product(101, "TRS-80 Model I", "Radio Shack", 1977, "USA", "Z80"),),
#  (Product(102, "TRS-80 MC-10", "Radio Shack", 1983, "USA", "6803"),),
#  (Product(103, "Tandy 1000", "Radio Shack", 1987, "USA", "8088"),),
#  (Product(104, "Euro PC", "Schneider Computer Division", 1988, "Germany", "8088"),),
#  (Product(105, "Oric 1", "Tangerine Computer Systems", 1983, "UK", "6502"),),
#  (Product(106, "Oric Atmos", "Tangerine Computer Systems", 1984, "UK", "6502"),),
#  (Product(107, "Oric Telestrat", "Tangerine Computer Systems", 1986, "UK", "6502"),),
#  (Product(108, "Galeb", "PEL Varaždin", 1981, "Croatia", "6502"),),
#  (Product(109, "Orao", "PEL Varaždin", 1984, "Croatia", "6502"),),
#  (Product(110, "P2000", "Philips", 1980, "Netherlands", "Z80"),),
#  (Product(111, "G7480", "Philips", 1983, "Netherlands", "Z80"),),
#  (Product(112, "Philips :YES", "Philips", 1985, "Netherlands", "80186"),),
#  (Product(113, "Pravetz 8", "Pravetz", 1985, "Bulgaria", "CM630 (6502 clone)"),),
#  (Product(114, "Pravetz 8D", "Pravetz", 1982, "Bulgaria", "6502"),),
#  (Product(115, "IMKO-1", "Pravetz", 1980, "Bulgaria", "6502"),),
#  (Product(116, "Poly-1", "Progeni Systems / Polycorp", 1981, "New Zealand", "6809"),),
#  (Product(117, "Prológica CP-400", "Prológica", 1984, "Brazil", "6809"),),
#  (Product(118, "KC 85", "VEB Robotron", 1984, "East Germany", "Z80 compatible"),),
#  (Product(119, "KC 87", "VEB Robotron", 1987, "East Germany", "Z80 compatible"),),
#  (Product(120, "Z1013", "VEB Robotron", 1985, "East Germany", "Z80 compatible"),),
#  (Product(121, "SC-3000", "Sega", 1983, "Japan", "Z80 compatible"),),
#  (Product(122, "MZ", "Sharp", 1979, "Japan", "Z80 compatible"),),
#  (Product(123, "Sharp X1", "Sharp", 1982, "Japan", "Z80 compatible"),),
#  (Product(124, "Sharp X68000", "Sharp", 1987, "Japan", "68000"),),
#  (Product(125, "ZX80", "Sinclair Research", 1980, "UK", "Z80"),),
#  (Product(126, "ZX81", "Sinclair Research", 1981, "UK", "Z80"),),
#  (Product(127, "ZX Spectrum", "Sinclair Research", 1982, "UK", "Z80"),),
#  (Product(128, "Sinclair QL", "Sinclair Research", 1984, "UK", "68008"),),
#  (Product(129, "Sord M200 Smart Home Computer", "Sord Computer Corporation", 1977, "Japan", "Z80"),),
#  (Product(130, "Sord M5", "Sord Computer Corporation", 1982, "Japan", "Z80"),),
#  (Product(131, "Aamber Pegasus", "Technosys", 1984, "New Zealand", "6809"),),
#  (Product(132, "TI-99/4", "Texas Instruments", 1979, "USA", "TMS 9900"),),
#  (Product(133, "TI-99/4A", "Texas Instruments", 1979, "USA", "TMS 9900"),),
#  (Product(134, "PMD 85", "Tesla", 1985, "Czechoslovakia", "8080"),),
#  (Product(135, "MAŤO", "Štátny majetok Závadka š.p.", 1989, "Czechoslovakia", "8080"),),
#  (Product(136, "TO7", "Thomson", 1982, "France", "6809"),),
#  (Product(137, "MO5", "Thomson", 1984, "France", "6809"),),
#  (Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),),
#  (Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),),
#  (Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80"),),
#  (Product(141, "Timex Computer 2048", "Timex Sinclair", 1984, "Portugal", "Z80"),),
#  (Product(142, "Timex Computer 2068", "Timex Sinclair", 1983, "USA/UK/Portugal", "Z80"),),
#  (Product(143, "Komputer 2086", "Timex Sinclair", 1986, "Portugal/Poland", "Z80"),),
#  (Product(144, "Tomy Tutor", "Tomy", 1986, "Japan", "TMS 9900"),),
#  (Product(145, "Vector-06C", "Vector", 1987, "USSR", "8080 compatible"),),
#  (Product(146, "VideoBrain Family Computer", "Videobrain", 1977, "USA", "Fairchild F8"),),
#  (Product(147, "TVC", "Videoton", 1986, "Hungary", "Z80"),),
#  (Product(148, "West PC-800", "West Computer AS", 1984, "Norway", "6502, Z80"),),
#  (Product(149, "GEM 1000", "GEM", 1985, "Belgium", "Z80"),)]

# %%
r = session.execute(q)
for row in r:
    print(row)
# Out:
# (Product(1, "Acorn Atom", "Acorn Computers Ltd", 1980, "UK", "6502"),)
# (Product(2, "BBC Micro", "Acorn Computers Ltd", 1981, "UK", "6502"),)
# (Product(3, "Electron", "Acorn Computers Ltd", 1983, "UK", "6502"),)
# (Product(4, "BBC Master", "Acorn Computers Ltd", 1986, "UK", "65SC12"),)
# (Product(5, "Acorn Archimedes", "Acorn Computers Ltd", 1987, "UK", "ARM RISC"),)
# (Product(6, "A7000", "Acorn Computers Ltd", 1995, "UK", "ARM RISC"),)
# (Product(7, "CPC 464", "Amstrad", 1984, "UK", "Z80"),)
# (Product(8, "CPC 664", "Amstrad", 1984, "UK", "Z80"),)
# (Product(9, "CPC 6128", "Amstrad", 1984, "UK", "Z80"),)
# (Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),)
# (Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),)
# (Product(12, "PCW", "Amstrad", 1985, "UK", "Z80"),)
# (Product(13, "PC-1512", "Amstrad", 1986, "UK", "8086"),)
# (Product(14, "CEC-I Zhonghua", "Tsinghua University", 1986, "China", "6502"),)
# (Product(15, "Imagination Machine", "APF Electronics, Inc.", 1979, "USA", "6800"),)
# (Product(16, "Apple II", "Apple Computer", 1977, "USA", "6502"),)
# (Product(17, "Apple IIe", "Apple Computer", 1983, "USA", "6502"),)
# (Product(18, "Apple IIc", "Apple Computer", 1984, "USA", "65C02"),)
# (Product(19, "Apple IIc Plus", "Apple Computer", 1988, "USA", "65C02"),)
# (Product(20, "Apple II Plus", "Apple Computer", 1979, "USA", "6502"),)
# (Product(21, "Apple IIGS", "Apple Computer", 1986, "USA", "65C816"),)
# (Product(22, "Apricot F1", "Apricot Computers", 1984, "UK", "8088"),)
# (Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80"),)
# (Product(24, "Atari 400", "Atari, Inc.", 1979, "USA", "6502"),)
# (Product(25, "Atari 800", "Atari, Inc.", 1979, "USA", "6502"),)
# (Product(26, "Atari 1200XL", "Atari, Inc.", 1983, "USA", "6502"),)
# (Product(27, "Atari 600XL", "Atari, Inc.", 1983, "USA", "6502"),)
# (Product(28, "Atari 800XL", "Atari, Inc.", 1983, "USA", "6502"),)
# (Product(29, "Atari 65XE", "Atari, Inc.", 1985, "USA", "6502C"),)
# (Product(30, "Atari 130XE", "Atari, Inc.", 1985, "USA", "6502C"),)
# (Product(31, "Atari ST", "Atari Corporation", 1985, "USA", "68000"),)
# (Product(32, "Atari TT", "Atari Corporation", 1990, "USA", "68030"),)
# (Product(33, "Falcon", "Atari Corporation", 1992, "USA", "68030 + 56001"),)
# (Product(34, "Bally Brain", "Bally Consumer Products", 1979, "USA", "Z80"),)
# (Product(35, "Bally Astrocade", "Bally Consumer Products", 1977, "USA", "Z80"),)
# (Product(36, "CoBra", "Brasov Computer", 1986, "Romania", "Z80"),)
# (Product(37, "Lynx", "Camputers", 1983, "UK", "Z80"),)
# (Product(38, "Coleco Adam", "Coleco", 1983, "USA", "Z80"),)
# (Product(39, "PET", "Commodore", 1977, "USA", "6502"),)
# (Product(40, "VIC-20", "Commodore", 1980, "USA", "6502"),)
# (Product(41, "Commodore 64", "Commodore", 1982, "USA", "6510"),)
# (Product(42, "Commodore Executive 64", "Commodore", 1982, "USA", "6510"),)
# (Product(43, "MAX Machine", "Commodore", 1982, "USA", "6510"),)
# (Product(44, "Commodore 16", "Commodore", 1984, "USA", "8501 (6502)"),)
# (Product(45, "Commodore 116", "Commodore", 1984, "USA", "8501 (6502)"),)
# (Product(46, "Plus/4", "Commodore", 1984, "USA", "8501 (6502)"),)
# (Product(47, "Commodore 128", "Commodore", 1985, "USA", "8502 (6502) / Z80"),)
# (Product(48, "Amiga", "Commodore", 1985, "USA", "68000 (family)"),)
# (Product(49, "Comx-35", "Comx World Operations", 1983, "Hong Kong", "RCA 1802"),)
# (Product(50, "DAI Personal Computer", "Data Applications International", 1980, "Belgium", "8080"),)
# (Product(51, "VTech Laser 200", "Vtech", 1985, "Hong Kong", "Z80"),)
# (Product(52, "Video Genie", "EACA", 1980, "Hong Kong", "Z80"),)
# (Product(53, "Colour Genie", "EACA", 1983, "Hong Kong", "Z80"),)
# (Product(54, "Rabbit RX83", "Rabbit", 1983, "Hong Kong", "Z80"),)
# (Product(55, "Alpha", "Didaktik", 1986, "Czechoslovakia", "Z80"),)
# (Product(56, "Beta", "Didaktik", 1986, "Czechoslovakia", "Z80"),)
# (Product(57, "Gama", "Didaktik", 1987, "Czechoslovakia", "Z80"),)
# (Product(58, "Dragon 32", "Dragon Data", 1982, "UK", "6809"),)
# (Product(59, "Dragon 64", "Dragon Data", 1982, "UK", "6809"),)
# (Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),)
# (Product(61, "BK-0010", "Elektronika", 1985, "USSR", "PDP 11 (compatible)"),)
# (Product(62, "AGAT-9", "AGAT", 1984, "USSR", "Native/Apple II compatible"),)
# (Product(63, "Pecom 32", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),)
# (Product(64, "Pecom 64", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),)
# (Product(65, "Exidy Sorcerer", "Exidy", 1978, "USA", "Z80"),)
# (Product(66, "Enterprise 64", "Intelligent Software", 1985, "UK", "Z80"),)
# (Product(67, "Enterprise 128", "Intelligent Software", 1985, "UK", "Z80"),)
# (Product(68, "Lambda 8300", "Lambda Electronics", 1985, "Hong Kong", "Z80"),)
# (Product(69, "Franklin ACE", "Franklin Computer Corporation", 1982, "USA", "6502"),)
# (Product(70, "FM Towns", "Fujitsu", 1989, "Japan", "80386SX"),)
# (Product(71, "FM-7", "Fujitsu", 1982, "Japan", "6809"),)
# (Product(72, "Grundy NewBrain", "Grundy Business Systems", 1982, "UK", "Z80"),)
# (Product(73, "Gradiente Expert", "Gradiente", 1985, "Brazil", "Z80"),)
# (Product(74, "Honeywell 316", "Honeywell", 1969, "USA", "DDP 16 Minicomputer"),)
# (Product(75, "PCjr", "IBM", 1984, "USA", "8088"),)
# (Product(76, "IBM PS/1", "IBM", 1990, "USA", "8088"),)
# (Product(77, "Interact Home Computer", "Interact", 1979, "USA", "8080"),)
# (Product(78, "Compucolor II", "Intelligent Systems Corporation", 1977, "USA", "8080"),)
# (Product(79, "Hobbit", "Intercompex", 1990, "USSR", "Z80 compatible"),)
# (Product(80, "Iskra-1030", "Iskra", 1989, "USSR", "8086 compatible"),)
# (Product(81, "Ivel Ultra", "Ivasim", 1984, "Croatia", "6502 compatible"),)
# (Product(82, "Ivel Z3", "Ivasim", 1983, "Croatia", "6502 compatible"),)
# (Product(83, "Jupiter ACE", "Jupiter Cantab", 1982, "UK", "Z80"),)
# (Product(84, "ABC 80", "Luxor", 1978, "Sweden", "Z80"),)
# (Product(85, "Aquarius", "Mattel", 1983, "USA", "Z80"),)
# (Product(86, "Matra Alice", "Matra", 1983, "France", "6803"),)
# (Product(87, "MTX500", "Memotech", 1983, "UK", "Z80"),)
# (Product(88, "MTX512", "Memotech", 1983, "UK", "Z80"),)
# (Product(89, "RS128", "Memotech", 1983, "UK", "Z80"),)
# (Product(90, "MicroBee", "Microbee Systems", 1983, "Australia", "Z80"),)
# (Product(91, "CCE MC-1000", "Comércio de Componentes Eletrônicos", 1985, "Brazil", "Z80"),)
# (Product(92, "TK82C", "Microdigital Eletronica", 1985, "Brazil", "Z80"),)
# (Product(93, "SAM Coupé", "Miles Gordon Technology", 1989, "UK", "Z80"),)
# (Product(94, "Microprofessor III", "Multitech", 1983, "Taiwan", "6502"),)
# (Product(95, "NEC PC-100", "NEC", 1983, "Japan", "8086"),)
# (Product(96, "PC-6000", "NEC Home Electronics", 1981, "Japan", "Z80"),)
# (Product(97, "PC-8800", "NEC", 1981, "Japan", "Z80"),)
# (Product(98, "TRS-80 Color Computer", "Radio Shack", 1980, "USA", "6809"),)
# (Product(99, "TRS-80 Color Computer 2", "Radio Shack", 1980, "USA", "6809"),)
# (Product(100, "TRS-80 Color Computer 3", "Radio Shack", 1980, "USA", "6809"),)
# (Product(101, "TRS-80 Model I", "Radio Shack", 1977, "USA", "Z80"),)
# (Product(102, "TRS-80 MC-10", "Radio Shack", 1983, "USA", "6803"),)
# (Product(103, "Tandy 1000", "Radio Shack", 1987, "USA", "8088"),)
# (Product(104, "Euro PC", "Schneider Computer Division", 1988, "Germany", "8088"),)
# (Product(105, "Oric 1", "Tangerine Computer Systems", 1983, "UK", "6502"),)
# (Product(106, "Oric Atmos", "Tangerine Computer Systems", 1984, "UK", "6502"),)
# (Product(107, "Oric Telestrat", "Tangerine Computer Systems", 1986, "UK", "6502"),)
# (Product(108, "Galeb", "PEL Varaždin", 1981, "Croatia", "6502"),)
# (Product(109, "Orao", "PEL Varaždin", 1984, "Croatia", "6502"),)
# (Product(110, "P2000", "Philips", 1980, "Netherlands", "Z80"),)
# (Product(111, "G7480", "Philips", 1983, "Netherlands", "Z80"),)
# (Product(112, "Philips :YES", "Philips", 1985, "Netherlands", "80186"),)
# (Product(113, "Pravetz 8", "Pravetz", 1985, "Bulgaria", "CM630 (6502 clone)"),)
# (Product(114, "Pravetz 8D", "Pravetz", 1982, "Bulgaria", "6502"),)
# (Product(115, "IMKO-1", "Pravetz", 1980, "Bulgaria", "6502"),)
# (Product(116, "Poly-1", "Progeni Systems / Polycorp", 1981, "New Zealand", "6809"),)
# (Product(117, "Prológica CP-400", "Prológica", 1984, "Brazil", "6809"),)
# (Product(118, "KC 85", "VEB Robotron", 1984, "East Germany", "Z80 compatible"),)
# (Product(119, "KC 87", "VEB Robotron", 1987, "East Germany", "Z80 compatible"),)
# (Product(120, "Z1013", "VEB Robotron", 1985, "East Germany", "Z80 compatible"),)
# (Product(121, "SC-3000", "Sega", 1983, "Japan", "Z80 compatible"),)
# (Product(122, "MZ", "Sharp", 1979, "Japan", "Z80 compatible"),)
# (Product(123, "Sharp X1", "Sharp", 1982, "Japan", "Z80 compatible"),)
# (Product(124, "Sharp X68000", "Sharp", 1987, "Japan", "68000"),)
# (Product(125, "ZX80", "Sinclair Research", 1980, "UK", "Z80"),)
# (Product(126, "ZX81", "Sinclair Research", 1981, "UK", "Z80"),)
# (Product(127, "ZX Spectrum", "Sinclair Research", 1982, "UK", "Z80"),)
# (Product(128, "Sinclair QL", "Sinclair Research", 1984, "UK", "68008"),)
# (Product(129, "Sord M200 Smart Home Computer", "Sord Computer Corporation", 1977, "Japan", "Z80"),)
# (Product(130, "Sord M5", "Sord Computer Corporation", 1982, "Japan", "Z80"),)
# (Product(131, "Aamber Pegasus", "Technosys", 1984, "New Zealand", "6809"),)
# (Product(132, "TI-99/4", "Texas Instruments", 1979, "USA", "TMS 9900"),)
# (Product(133, "TI-99/4A", "Texas Instruments", 1979, "USA", "TMS 9900"),)
# (Product(134, "PMD 85", "Tesla", 1985, "Czechoslovakia", "8080"),)
# (Product(135, "MAŤO", "Štátny majetok Závadka š.p.", 1989, "Czechoslovakia", "8080"),)
# (Product(136, "TO7", "Thomson", 1982, "France", "6809"),)
# (Product(137, "MO5", "Thomson", 1984, "France", "6809"),)
# (Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),)
# (Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),)
# (Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80"),)
# (Product(141, "Timex Computer 2048", "Timex Sinclair", 1984, "Portugal", "Z80"),)
# (Product(142, "Timex Computer 2068", "Timex Sinclair", 1983, "USA/UK/Portugal", "Z80"),)
# (Product(143, "Komputer 2086", "Timex Sinclair", 1986, "Portugal/Poland", "Z80"),)
# (Product(144, "Tomy Tutor", "Tomy", 1986, "Japan", "TMS 9900"),)
# (Product(145, "Vector-06C", "Vector", 1987, "USSR", "8080 compatible"),)
# (Product(146, "VideoBrain Family Computer", "Videobrain", 1977, "USA", "Fairchild F8"),)
# (Product(147, "TVC", "Videoton", 1986, "Hungary", "Z80"),)
# (Product(148, "West PC-800", "West Computer AS", 1984, "Norway", "6502, Z80"),)
# (Product(149, "GEM 1000", "GEM", 1985, "Belgium", "Z80"),)

# %% [markdown]
# This isn't a simple Product instance. SQLAlchemy returns each result as a tuple, because queries can sometimes return multiple values per row (you will see examples of this shortly). Since SQLAlchemy does not know how many results per row are expected, it always returns each row as a tuple. This query returns a single value per row, so each tuple has a single element in it.

# %% [markdown]
# IF you know that you will be receieving a single value per row, then you can use the scalars() convenience method to execute the query:

# %%
session.scalars(q).all()
# Out:
# [Product(1, "Acorn Atom", "Acorn Computers Ltd", 1980, "UK", "6502"),
#  Product(2, "BBC Micro", "Acorn Computers Ltd", 1981, "UK", "6502"),
#  Product(3, "Electron", "Acorn Computers Ltd", 1983, "UK", "6502"),
#  Product(4, "BBC Master", "Acorn Computers Ltd", 1986, "UK", "65SC12"),
#  Product(5, "Acorn Archimedes", "Acorn Computers Ltd", 1987, "UK", "ARM RISC"),
#  Product(6, "A7000", "Acorn Computers Ltd", 1995, "UK", "ARM RISC"),
#  Product(7, "CPC 464", "Amstrad", 1984, "UK", "Z80"),
#  Product(8, "CPC 664", "Amstrad", 1984, "UK", "Z80"),
#  Product(9, "CPC 6128", "Amstrad", 1984, "UK", "Z80"),
#  Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),
#  Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),
#  Product(12, "PCW", "Amstrad", 1985, "UK", "Z80"),
#  Product(13, "PC-1512", "Amstrad", 1986, "UK", "8086"),
#  Product(14, "CEC-I Zhonghua", "Tsinghua University", 1986, "China", "6502"),
#  Product(15, "Imagination Machine", "APF Electronics, Inc.", 1979, "USA", "6800"),
#  Product(16, "Apple II", "Apple Computer", 1977, "USA", "6502"),
#  Product(17, "Apple IIe", "Apple Computer", 1983, "USA", "6502"),
#  Product(18, "Apple IIc", "Apple Computer", 1984, "USA", "65C02"),
#  Product(19, "Apple IIc Plus", "Apple Computer", 1988, "USA", "65C02"),
#  Product(20, "Apple II Plus", "Apple Computer", 1979, "USA", "6502"),
#  Product(21, "Apple IIGS", "Apple Computer", 1986, "USA", "65C816"),
#  Product(22, "Apricot F1", "Apricot Computers", 1984, "UK", "8088"),
#  Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80"),
#  Product(24, "Atari 400", "Atari, Inc.", 1979, "USA", "6502"),
#  Product(25, "Atari 800", "Atari, Inc.", 1979, "USA", "6502"),
#  Product(26, "Atari 1200XL", "Atari, Inc.", 1983, "USA", "6502"),
#  Product(27, "Atari 600XL", "Atari, Inc.", 1983, "USA", "6502"),
#  Product(28, "Atari 800XL", "Atari, Inc.", 1983, "USA", "6502"),
#  Product(29, "Atari 65XE", "Atari, Inc.", 1985, "USA", "6502C"),
#  Product(30, "Atari 130XE", "Atari, Inc.", 1985, "USA", "6502C"),
#  Product(31, "Atari ST", "Atari Corporation", 1985, "USA", "68000"),
#  Product(32, "Atari TT", "Atari Corporation", 1990, "USA", "68030"),
#  Product(33, "Falcon", "Atari Corporation", 1992, "USA", "68030 + 56001"),
#  Product(34, "Bally Brain", "Bally Consumer Products", 1979, "USA", "Z80"),
#  Product(35, "Bally Astrocade", "Bally Consumer Products", 1977, "USA", "Z80"),
#  Product(36, "CoBra", "Brasov Computer", 1986, "Romania", "Z80"),
#  Product(37, "Lynx", "Camputers", 1983, "UK", "Z80"),
#  Product(38, "Coleco Adam", "Coleco", 1983, "USA", "Z80"),
#  Product(39, "PET", "Commodore", 1977, "USA", "6502"),
#  Product(40, "VIC-20", "Commodore", 1980, "USA", "6502"),
#  Product(41, "Commodore 64", "Commodore", 1982, "USA", "6510"),
#  Product(42, "Commodore Executive 64", "Commodore", 1982, "USA", "6510"),
#  Product(43, "MAX Machine", "Commodore", 1982, "USA", "6510"),
#  Product(44, "Commodore 16", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(45, "Commodore 116", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(46, "Plus/4", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(47, "Commodore 128", "Commodore", 1985, "USA", "8502 (6502) / Z80"),
#  Product(48, "Amiga", "Commodore", 1985, "USA", "68000 (family)"),
#  Product(49, "Comx-35", "Comx World Operations", 1983, "Hong Kong", "RCA 1802"),
#  Product(50, "DAI Personal Computer", "Data Applications International", 1980, "Belgium", "8080"),
#  Product(51, "VTech Laser 200", "Vtech", 1985, "Hong Kong", "Z80"),
#  Product(52, "Video Genie", "EACA", 1980, "Hong Kong", "Z80"),
#  Product(53, "Colour Genie", "EACA", 1983, "Hong Kong", "Z80"),
#  Product(54, "Rabbit RX83", "Rabbit", 1983, "Hong Kong", "Z80"),
#  Product(55, "Alpha", "Didaktik", 1986, "Czechoslovakia", "Z80"),
#  Product(56, "Beta", "Didaktik", 1986, "Czechoslovakia", "Z80"),
#  Product(57, "Gama", "Didaktik", 1987, "Czechoslovakia", "Z80"),
#  Product(58, "Dragon 32", "Dragon Data", 1982, "UK", "6809"),
#  Product(59, "Dragon 64", "Dragon Data", 1982, "UK", "6809"),
#  Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),
#  Product(61, "BK-0010", "Elektronika", 1985, "USSR", "PDP 11 (compatible)"),
#  Product(62, "AGAT-9", "AGAT", 1984, "USSR", "Native/Apple II compatible"),
#  Product(63, "Pecom 32", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),
#  Product(64, "Pecom 64", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),
#  Product(65, "Exidy Sorcerer", "Exidy", 1978, "USA", "Z80"),
#  Product(66, "Enterprise 64", "Intelligent Software", 1985, "UK", "Z80"),
#  Product(67, "Enterprise 128", "Intelligent Software", 1985, "UK", "Z80"),
#  Product(68, "Lambda 8300", "Lambda Electronics", 1985, "Hong Kong", "Z80"),
#  Product(69, "Franklin ACE", "Franklin Computer Corporation", 1982, "USA", "6502"),
#  Product(70, "FM Towns", "Fujitsu", 1989, "Japan", "80386SX"),
#  Product(71, "FM-7", "Fujitsu", 1982, "Japan", "6809"),
#  Product(72, "Grundy NewBrain", "Grundy Business Systems", 1982, "UK", "Z80"),
#  Product(73, "Gradiente Expert", "Gradiente", 1985, "Brazil", "Z80"),
#  Product(74, "Honeywell 316", "Honeywell", 1969, "USA", "DDP 16 Minicomputer"),
#  Product(75, "PCjr", "IBM", 1984, "USA", "8088"),
#  Product(76, "IBM PS/1", "IBM", 1990, "USA", "8088"),
#  Product(77, "Interact Home Computer", "Interact", 1979, "USA", "8080"),
#  Product(78, "Compucolor II", "Intelligent Systems Corporation", 1977, "USA", "8080"),
#  Product(79, "Hobbit", "Intercompex", 1990, "USSR", "Z80 compatible"),
#  Product(80, "Iskra-1030", "Iskra", 1989, "USSR", "8086 compatible"),
#  Product(81, "Ivel Ultra", "Ivasim", 1984, "Croatia", "6502 compatible"),
#  Product(82, "Ivel Z3", "Ivasim", 1983, "Croatia", "6502 compatible"),
#  Product(83, "Jupiter ACE", "Jupiter Cantab", 1982, "UK", "Z80"),
#  Product(84, "ABC 80", "Luxor", 1978, "Sweden", "Z80"),
#  Product(85, "Aquarius", "Mattel", 1983, "USA", "Z80"),
#  Product(86, "Matra Alice", "Matra", 1983, "France", "6803"),
#  Product(87, "MTX500", "Memotech", 1983, "UK", "Z80"),
#  Product(88, "MTX512", "Memotech", 1983, "UK", "Z80"),
#  Product(89, "RS128", "Memotech", 1983, "UK", "Z80"),
#  Product(90, "MicroBee", "Microbee Systems", 1983, "Australia", "Z80"),
#  Product(91, "CCE MC-1000", "Comércio de Componentes Eletrônicos", 1985, "Brazil", "Z80"),
#  Product(92, "TK82C", "Microdigital Eletronica", 1985, "Brazil", "Z80"),
#  Product(93, "SAM Coupé", "Miles Gordon Technology", 1989, "UK", "Z80"),
#  Product(94, "Microprofessor III", "Multitech", 1983, "Taiwan", "6502"),
#  Product(95, "NEC PC-100", "NEC", 1983, "Japan", "8086"),
#  Product(96, "PC-6000", "NEC Home Electronics", 1981, "Japan", "Z80"),
#  Product(97, "PC-8800", "NEC", 1981, "Japan", "Z80"),
#  Product(98, "TRS-80 Color Computer", "Radio Shack", 1980, "USA", "6809"),
#  Product(99, "TRS-80 Color Computer 2", "Radio Shack", 1980, "USA", "6809"),
#  Product(100, "TRS-80 Color Computer 3", "Radio Shack", 1980, "USA", "6809"),
#  Product(101, "TRS-80 Model I", "Radio Shack", 1977, "USA", "Z80"),
#  Product(102, "TRS-80 MC-10", "Radio Shack", 1983, "USA", "6803"),
#  Product(103, "Tandy 1000", "Radio Shack", 1987, "USA", "8088"),
#  Product(104, "Euro PC", "Schneider Computer Division", 1988, "Germany", "8088"),
#  Product(105, "Oric 1", "Tangerine Computer Systems", 1983, "UK", "6502"),
#  Product(106, "Oric Atmos", "Tangerine Computer Systems", 1984, "UK", "6502"),
#  Product(107, "Oric Telestrat", "Tangerine Computer Systems", 1986, "UK", "6502"),
#  Product(108, "Galeb", "PEL Varaždin", 1981, "Croatia", "6502"),
#  Product(109, "Orao", "PEL Varaždin", 1984, "Croatia", "6502"),
#  Product(110, "P2000", "Philips", 1980, "Netherlands", "Z80"),
#  Product(111, "G7480", "Philips", 1983, "Netherlands", "Z80"),
#  Product(112, "Philips :YES", "Philips", 1985, "Netherlands", "80186"),
#  Product(113, "Pravetz 8", "Pravetz", 1985, "Bulgaria", "CM630 (6502 clone)"),
#  Product(114, "Pravetz 8D", "Pravetz", 1982, "Bulgaria", "6502"),
#  Product(115, "IMKO-1", "Pravetz", 1980, "Bulgaria", "6502"),
#  Product(116, "Poly-1", "Progeni Systems / Polycorp", 1981, "New Zealand", "6809"),
#  Product(117, "Prológica CP-400", "Prológica", 1984, "Brazil", "6809"),
#  Product(118, "KC 85", "VEB Robotron", 1984, "East Germany", "Z80 compatible"),
#  Product(119, "KC 87", "VEB Robotron", 1987, "East Germany", "Z80 compatible"),
#  Product(120, "Z1013", "VEB Robotron", 1985, "East Germany", "Z80 compatible"),
#  Product(121, "SC-3000", "Sega", 1983, "Japan", "Z80 compatible"),
#  Product(122, "MZ", "Sharp", 1979, "Japan", "Z80 compatible"),
#  Product(123, "Sharp X1", "Sharp", 1982, "Japan", "Z80 compatible"),
#  Product(124, "Sharp X68000", "Sharp", 1987, "Japan", "68000"),
#  Product(125, "ZX80", "Sinclair Research", 1980, "UK", "Z80"),
#  Product(126, "ZX81", "Sinclair Research", 1981, "UK", "Z80"),
#  Product(127, "ZX Spectrum", "Sinclair Research", 1982, "UK", "Z80"),
#  Product(128, "Sinclair QL", "Sinclair Research", 1984, "UK", "68008"),
#  Product(129, "Sord M200 Smart Home Computer", "Sord Computer Corporation", 1977, "Japan", "Z80"),
#  Product(130, "Sord M5", "Sord Computer Corporation", 1982, "Japan", "Z80"),
#  Product(131, "Aamber Pegasus", "Technosys", 1984, "New Zealand", "6809"),
#  Product(132, "TI-99/4", "Texas Instruments", 1979, "USA", "TMS 9900"),
#  Product(133, "TI-99/4A", "Texas Instruments", 1979, "USA", "TMS 9900"),
#  Product(134, "PMD 85", "Tesla", 1985, "Czechoslovakia", "8080"),
#  Product(135, "MAŤO", "Štátny majetok Závadka š.p.", 1989, "Czechoslovakia", "8080"),
#  Product(136, "TO7", "Thomson", 1982, "France", "6809"),
#  Product(137, "MO5", "Thomson", 1984, "France", "6809"),
#  Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80"),
#  Product(141, "Timex Computer 2048", "Timex Sinclair", 1984, "Portugal", "Z80"),
#  Product(142, "Timex Computer 2068", "Timex Sinclair", 1983, "USA/UK/Portugal", "Z80"),
#  Product(143, "Komputer 2086", "Timex Sinclair", 1986, "Portugal/Poland", "Z80"),
#  Product(144, "Tomy Tutor", "Tomy", 1986, "Japan", "TMS 9900"),
#  Product(145, "Vector-06C", "Vector", 1987, "USSR", "8080 compatible"),
#  Product(146, "VideoBrain Family Computer", "Videobrain", 1977, "USA", "Fairchild F8"),
#  Product(147, "TVC", "Videoton", 1986, "Hungary", "Z80"),
#  Product(148, "West PC-800", "West Computer AS", 1984, "Norway", "6502, Z80"),
#  Product(149, "GEM 1000", "GEM", 1985, "Belgium", "Z80")]

# %% [markdown]
# The next example shows a compact way to get the first value of the first result row:

# %%
r = session.scalar(q)
r
# Out:
# Product(1, "Acorn Atom", "Acorn Computers Ltd", 1980, "UK", "6502")

# %%
q = select(Product).where(Product.manufacturer == "Commodore")
session.scalars(q).all()
# Out:
# [Product(39, "PET", "Commodore", 1977, "USA", "6502"),
#  Product(40, "VIC-20", "Commodore", 1980, "USA", "6502"),
#  Product(41, "Commodore 64", "Commodore", 1982, "USA", "6510"),
#  Product(42, "Commodore Executive 64", "Commodore", 1982, "USA", "6510"),
#  Product(43, "MAX Machine", "Commodore", 1982, "USA", "6510"),
#  Product(44, "Commodore 16", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(45, "Commodore 116", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(46, "Plus/4", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(47, "Commodore 128", "Commodore", 1985, "USA", "8502 (6502) / Z80"),
#  Product(48, "Amiga", "Commodore", 1985, "USA", "68000 (family)")]

# %%
q = select(Product).where(Product.year >= 1990)
session.scalars(q).all()
# Out:
# [Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),
#  Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),
#  Product(32, "Atari TT", "Atari Corporation", 1990, "USA", "68030"),
#  Product(76, "IBM PS/1", "IBM", 1990, "USA", "8088"),
#  Product(79, "Hobbit", "Intercompex", 1990, "USSR", "Z80 compatible"),
#  Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),
#  Product(33, "Falcon", "Atari Corporation", 1992, "USA", "68030 + 56001"),
#  Product(6, "A7000", "Acorn Computers Ltd", 1995, "UK", "ARM RISC")]

# %%
q = (select(Product)
     .where(Product.manufacturer == "Commodore")
     .where(Product.year == 1980))
session.scalars(q).all()
# Out:
# [Product(40, "VIC-20", "Commodore", 1980, "USA", "6502")]

# %%
q = select(Product).where(Product.manufacturer == "Commodore",
            Product.year == 1980)
session.scalars(q).all()
# Out:
# [Product(40, "VIC-20", "Commodore", 1980, "USA", "6502")]

# %% [markdown]
# Combining multiple filters as shown above effecively applies the AND logical operator to them. Sometimes a query may need to combine filters with the OR operator, which SQLAlchemy offers with the or_() function. The next example returns products built before 1970 or afte 1990:

# %%
from sqlalchemy import or_
q = select(Product).where(or_(Product.year < 1970,Product.year > 1990))
session.scalars(q).all()
# Out:
# [Product(74, "Honeywell 316", "Honeywell", 1969, "USA", "DDP 16 Minicomputer"),
#  Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),
#  Product(33, "Falcon", "Atari Corporation", 1992, "USA", "68030 + 56001"),
#  Product(6, "A7000", "Acorn Computers Ltd", 1995, "UK", "ARM RISC")]

# %% [markdown]
# Another very useful filter is the LIKE operator, which can be used to implement a simle searach function. The following example retrieves all products that have the word Sinclair in their name:

# %%
q = select(Product).where(Product.name.like("%Sinclair%"))
session.scalars(q).all()
# Out:
# [Product(128, "Sinclair QL", "Sinclair Research", 1984, "UK", "68008"),
#  Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80")]

# %%
q = select(Product).where(Product.name.ilike("%SINCLAIR%"))
session.scalars(q).all()
# Out:
# [Product(128, "Sinclair QL", "Sinclair Research", 1984, "UK", "68008"),
#  Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80")]

# %%
help(Product.name.ilike)
# Out:
# Help on method ilike in module sqlalchemy.sql.operators:
#
# ilike(other: 'Any', escape: 'Optional[str]' = None) -> 'ColumnOperators' method of sqlalchemy.orm.attributes.InstrumentedAttribute instance
#     Implement the ``ilike`` operator, e.g. case insensitive LIKE.
#
#     In a column context, produces an expression either of the form:
#
#     .. sourcecode:: sql
#
#         lower(a) LIKE lower(other)
#
#     Or on backends that support the ILIKE operator:
#
#     .. sourcecode:: sql
#
#         a ILIKE other
#
#     E.g.::
#
#         stmt = select(sometable).where(sometable.c.column.ilike("%foobar%"))
#
#     :param other: expression to be compared
#     :param escape: optional escape character, renders the ``ESCAPE``
#       keyword, e.g.::
#
#         somecolumn.ilike("foo/%bar", escape="/")
#
#     .. seealso::
#
#         :meth:`.ColumnOperators.like`

# %%
q = select(Product).where(Product.name.ilike("%SINCLAIR%"))
results = session.scalars(q).all()

# %%
results[0]
# Out:
# Product(128, "Sinclair QL", "Sinclair Research", 1984, "UK", "68008")

# %%
results[0].name
# Out:
# 'Sinclair QL'

# %% [markdown]
# But it looks like like itself is also case insensitive?

# %%
q = select(Product).where(Product.name.like("%SINCLAIR%"))
results = session.scalars(q).all()
results[0].name
# Out:
# 'Sinclair QL'

# %% [markdown]
# ● This is a great question, and your confusion is completely
#   understandable. The answer lies in SQLite's default behavior, not
#   SQLAlchemy.
#
#   SQLite's LIKE is case-insensitive by default (for ASCII)
#
#   You're using SQLite as your database (I can see sqlite3
#   chapter2/retrofun.sqlite in your notebook). Unlike PostgreSQL and most
#   other databases, SQLite's LIKE operator is case-insensitive by default
#   for ASCII characters (A-Z).
#
#   From SQLite's documentation:
#   SQLite only understands upper/lower case for ASCII characters by default.
#    The LIKE operator is case sensitive by default for unicode characters
#   that are beyond the ASCII range.
#
#   So when you run:
#   Product.name.like("%SINCLAIR%")
#
#   SQLite translates this to a case-insensitive comparison, matching
#   "Sinclair QL" even though you searched for "SINCLAIR".
#
#   Why does ilike exist then?
#
#   The ilike method is primarily useful for databases like PostgreSQL where
#   LIKE is case-sensitive. In PostgreSQL:
#   - LIKE '%SINCLAIR%' would not match "Sinclair QL"
#   - ILIKE '%SINCLAIR%' would match "Sinclair QL"
#
#   SQLAlchemy's ilike() generates lower(column) LIKE lower(pattern) for
#   databases that don't have native ILIKE support, ensuring portable
#   case-insensitive behavior across different database backends.
#
#   If you want case-sensitive LIKE in SQLite
#
#   You can enable it with:
#   PRAGMA case_sensitive_like = ON;
#
#   Or in SQLAlchemy, you could execute this pragma at connection time.
#
#   This is a common "gotcha" when learning SQL across different databases -
#   the same operator can behave differently depending on the backend.

# %%
q = select(Product).where(Product.year.between(1970,1978))
print(q)
# Out:
# SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.year BETWEEN :year_1 AND :year_2

# %%
print(q.compile(compile_kwargs={"literal_binds": True}))
# Out:
# SELECT products.id, products.name, products.manufacturer, products.year, products.country, products.cpu
# FROM products
# WHERE products.year BETWEEN 1970 AND 1978

# %%
q = select(Product).order_by(Product.name)
session.scalars(q).all()
# Out:
# [Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),
#  Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),
#  Product(6, "A7000", "Acorn Computers Ltd", 1995, "UK", "ARM RISC"),
#  Product(84, "ABC 80", "Luxor", 1978, "Sweden", "Z80"),
#  Product(62, "AGAT-9", "AGAT", 1984, "USSR", "Native/Apple II compatible"),
#  Product(131, "Aamber Pegasus", "Technosys", 1984, "New Zealand", "6809"),
#  Product(5, "Acorn Archimedes", "Acorn Computers Ltd", 1987, "UK", "ARM RISC"),
#  Product(1, "Acorn Atom", "Acorn Computers Ltd", 1980, "UK", "6502"),
#  Product(55, "Alpha", "Didaktik", 1986, "Czechoslovakia", "Z80"),
#  Product(48, "Amiga", "Commodore", 1985, "USA", "68000 (family)"),
#  Product(16, "Apple II", "Apple Computer", 1977, "USA", "6502"),
#  Product(20, "Apple II Plus", "Apple Computer", 1979, "USA", "6502"),
#  Product(21, "Apple IIGS", "Apple Computer", 1986, "USA", "65C816"),
#  Product(18, "Apple IIc", "Apple Computer", 1984, "USA", "65C02"),
#  Product(19, "Apple IIc Plus", "Apple Computer", 1988, "USA", "65C02"),
#  Product(17, "Apple IIe", "Apple Computer", 1983, "USA", "6502"),
#  Product(22, "Apricot F1", "Apricot Computers", 1984, "UK", "8088"),
#  Product(85, "Aquarius", "Mattel", 1983, "USA", "Z80"),
#  Product(26, "Atari 1200XL", "Atari, Inc.", 1983, "USA", "6502"),
#  Product(30, "Atari 130XE", "Atari, Inc.", 1985, "USA", "6502C"),
#  Product(24, "Atari 400", "Atari, Inc.", 1979, "USA", "6502"),
#  Product(27, "Atari 600XL", "Atari, Inc.", 1983, "USA", "6502"),
#  Product(29, "Atari 65XE", "Atari, Inc.", 1985, "USA", "6502C"),
#  Product(25, "Atari 800", "Atari, Inc.", 1979, "USA", "6502"),
#  Product(28, "Atari 800XL", "Atari, Inc.", 1983, "USA", "6502"),
#  Product(31, "Atari ST", "Atari Corporation", 1985, "USA", "68000"),
#  Product(32, "Atari TT", "Atari Corporation", 1990, "USA", "68030"),
#  Product(4, "BBC Master", "Acorn Computers Ltd", 1986, "UK", "65SC12"),
#  Product(2, "BBC Micro", "Acorn Computers Ltd", 1981, "UK", "6502"),
#  Product(61, "BK-0010", "Elektronika", 1985, "USSR", "PDP 11 (compatible)"),
#  Product(35, "Bally Astrocade", "Bally Consumer Products", 1977, "USA", "Z80"),
#  Product(34, "Bally Brain", "Bally Consumer Products", 1979, "USA", "Z80"),
#  Product(56, "Beta", "Didaktik", 1986, "Czechoslovakia", "Z80"),
#  Product(91, "CCE MC-1000", "Comércio de Componentes Eletrônicos", 1985, "Brazil", "Z80"),
#  Product(14, "CEC-I Zhonghua", "Tsinghua University", 1986, "China", "6502"),
#  Product(7, "CPC 464", "Amstrad", 1984, "UK", "Z80"),
#  Product(9, "CPC 6128", "Amstrad", 1984, "UK", "Z80"),
#  Product(8, "CPC 664", "Amstrad", 1984, "UK", "Z80"),
#  Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80"),
#  Product(36, "CoBra", "Brasov Computer", 1986, "Romania", "Z80"),
#  Product(38, "Coleco Adam", "Coleco", 1983, "USA", "Z80"),
#  Product(53, "Colour Genie", "EACA", 1983, "Hong Kong", "Z80"),
#  Product(45, "Commodore 116", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(47, "Commodore 128", "Commodore", 1985, "USA", "8502 (6502) / Z80"),
#  Product(44, "Commodore 16", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(41, "Commodore 64", "Commodore", 1982, "USA", "6510"),
#  Product(42, "Commodore Executive 64", "Commodore", 1982, "USA", "6510"),
#  Product(78, "Compucolor II", "Intelligent Systems Corporation", 1977, "USA", "8080"),
#  Product(49, "Comx-35", "Comx World Operations", 1983, "Hong Kong", "RCA 1802"),
#  Product(50, "DAI Personal Computer", "Data Applications International", 1980, "Belgium", "8080"),
#  Product(58, "Dragon 32", "Dragon Data", 1982, "UK", "6809"),
#  Product(59, "Dragon 64", "Dragon Data", 1982, "UK", "6809"),
#  Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),
#  Product(3, "Electron", "Acorn Computers Ltd", 1983, "UK", "6502"),
#  Product(67, "Enterprise 128", "Intelligent Software", 1985, "UK", "Z80"),
#  Product(66, "Enterprise 64", "Intelligent Software", 1985, "UK", "Z80"),
#  Product(104, "Euro PC", "Schneider Computer Division", 1988, "Germany", "8088"),
#  Product(65, "Exidy Sorcerer", "Exidy", 1978, "USA", "Z80"),
#  Product(70, "FM Towns", "Fujitsu", 1989, "Japan", "80386SX"),
#  Product(71, "FM-7", "Fujitsu", 1982, "Japan", "6809"),
#  Product(33, "Falcon", "Atari Corporation", 1992, "USA", "68030 + 56001"),
#  Product(69, "Franklin ACE", "Franklin Computer Corporation", 1982, "USA", "6502"),
#  Product(111, "G7480", "Philips", 1983, "Netherlands", "Z80"),
#  Product(149, "GEM 1000", "GEM", 1985, "Belgium", "Z80"),
#  Product(108, "Galeb", "PEL Varaždin", 1981, "Croatia", "6502"),
#  Product(57, "Gama", "Didaktik", 1987, "Czechoslovakia", "Z80"),
#  Product(73, "Gradiente Expert", "Gradiente", 1985, "Brazil", "Z80"),
#  Product(72, "Grundy NewBrain", "Grundy Business Systems", 1982, "UK", "Z80"),
#  Product(79, "Hobbit", "Intercompex", 1990, "USSR", "Z80 compatible"),
#  Product(74, "Honeywell 316", "Honeywell", 1969, "USA", "DDP 16 Minicomputer"),
#  Product(76, "IBM PS/1", "IBM", 1990, "USA", "8088"),
#  Product(115, "IMKO-1", "Pravetz", 1980, "Bulgaria", "6502"),
#  Product(15, "Imagination Machine", "APF Electronics, Inc.", 1979, "USA", "6800"),
#  Product(77, "Interact Home Computer", "Interact", 1979, "USA", "8080"),
#  Product(80, "Iskra-1030", "Iskra", 1989, "USSR", "8086 compatible"),
#  Product(81, "Ivel Ultra", "Ivasim", 1984, "Croatia", "6502 compatible"),
#  Product(82, "Ivel Z3", "Ivasim", 1983, "Croatia", "6502 compatible"),
#  Product(83, "Jupiter ACE", "Jupiter Cantab", 1982, "UK", "Z80"),
#  Product(118, "KC 85", "VEB Robotron", 1984, "East Germany", "Z80 compatible"),
#  Product(119, "KC 87", "VEB Robotron", 1987, "East Germany", "Z80 compatible"),
#  Product(143, "Komputer 2086", "Timex Sinclair", 1986, "Portugal/Poland", "Z80"),
#  Product(68, "Lambda 8300", "Lambda Electronics", 1985, "Hong Kong", "Z80"),
#  Product(37, "Lynx", "Camputers", 1983, "UK", "Z80"),
#  Product(43, "MAX Machine", "Commodore", 1982, "USA", "6510"),
#  Product(135, "MAŤO", "Štátny majetok Závadka š.p.", 1989, "Czechoslovakia", "8080"),
#  Product(137, "MO5", "Thomson", 1984, "France", "6809"),
#  Product(87, "MTX500", "Memotech", 1983, "UK", "Z80"),
#  Product(88, "MTX512", "Memotech", 1983, "UK", "Z80"),
#  Product(122, "MZ", "Sharp", 1979, "Japan", "Z80 compatible"),
#  Product(86, "Matra Alice", "Matra", 1983, "France", "6803"),
#  Product(90, "MicroBee", "Microbee Systems", 1983, "Australia", "Z80"),
#  Product(94, "Microprofessor III", "Multitech", 1983, "Taiwan", "6502"),
#  Product(95, "NEC PC-100", "NEC", 1983, "Japan", "8086"),
#  Product(109, "Orao", "PEL Varaždin", 1984, "Croatia", "6502"),
#  Product(105, "Oric 1", "Tangerine Computer Systems", 1983, "UK", "6502"),
#  Product(106, "Oric Atmos", "Tangerine Computer Systems", 1984, "UK", "6502"),
#  Product(107, "Oric Telestrat", "Tangerine Computer Systems", 1986, "UK", "6502"),
#  Product(110, "P2000", "Philips", 1980, "Netherlands", "Z80"),
#  Product(13, "PC-1512", "Amstrad", 1986, "UK", "8086"),
#  Product(96, "PC-6000", "NEC Home Electronics", 1981, "Japan", "Z80"),
#  Product(97, "PC-8800", "NEC", 1981, "Japan", "Z80"),
#  Product(12, "PCW", "Amstrad", 1985, "UK", "Z80"),
#  Product(75, "PCjr", "IBM", 1984, "USA", "8088"),
#  Product(39, "PET", "Commodore", 1977, "USA", "6502"),
#  Product(134, "PMD 85", "Tesla", 1985, "Czechoslovakia", "8080"),
#  Product(63, "Pecom 32", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),
#  Product(64, "Pecom 64", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),
#  Product(112, "Philips :YES", "Philips", 1985, "Netherlands", "80186"),
#  Product(46, "Plus/4", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(116, "Poly-1", "Progeni Systems / Polycorp", 1981, "New Zealand", "6809"),
#  Product(113, "Pravetz 8", "Pravetz", 1985, "Bulgaria", "CM630 (6502 clone)"),
#  Product(114, "Pravetz 8D", "Pravetz", 1982, "Bulgaria", "6502"),
#  Product(117, "Prológica CP-400", "Prológica", 1984, "Brazil", "6809"),
#  Product(89, "RS128", "Memotech", 1983, "UK", "Z80"),
#  Product(54, "Rabbit RX83", "Rabbit", 1983, "Hong Kong", "Z80"),
#  Product(93, "SAM Coupé", "Miles Gordon Technology", 1989, "UK", "Z80"),
#  Product(121, "SC-3000", "Sega", 1983, "Japan", "Z80 compatible"),
#  Product(123, "Sharp X1", "Sharp", 1982, "Japan", "Z80 compatible"),
#  Product(124, "Sharp X68000", "Sharp", 1987, "Japan", "68000"),
#  Product(128, "Sinclair QL", "Sinclair Research", 1984, "UK", "68008"),
#  Product(129, "Sord M200 Smart Home Computer", "Sord Computer Corporation", 1977, "Japan", "Z80"),
#  Product(130, "Sord M5", "Sord Computer Corporation", 1982, "Japan", "Z80"),
#  Product(132, "TI-99/4", "Texas Instruments", 1979, "USA", "TMS 9900"),
#  Product(133, "TI-99/4A", "Texas Instruments", 1979, "USA", "TMS 9900"),
#  Product(92, "TK82C", "Microdigital Eletronica", 1985, "Brazil", "Z80"),
#  Product(136, "TO7", "Thomson", 1982, "France", "6809"),
#  Product(98, "TRS-80 Color Computer", "Radio Shack", 1980, "USA", "6809"),
#  Product(99, "TRS-80 Color Computer 2", "Radio Shack", 1980, "USA", "6809"),
#  Product(100, "TRS-80 Color Computer 3", "Radio Shack", 1980, "USA", "6809"),
#  Product(102, "TRS-80 MC-10", "Radio Shack", 1983, "USA", "6803"),
#  Product(101, "TRS-80 Model I", "Radio Shack", 1977, "USA", "Z80"),
#  Product(147, "TVC", "Videoton", 1986, "Hungary", "Z80"),
#  Product(103, "Tandy 1000", "Radio Shack", 1987, "USA", "8088"),
#  Product(141, "Timex Computer 2048", "Timex Sinclair", 1984, "Portugal", "Z80"),
#  Product(142, "Timex Computer 2068", "Timex Sinclair", 1983, "USA/UK/Portugal", "Z80"),
#  Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80"),
#  Product(144, "Tomy Tutor", "Tomy", 1986, "Japan", "TMS 9900"),
#  Product(40, "VIC-20", "Commodore", 1980, "USA", "6502"),
#  Product(51, "VTech Laser 200", "Vtech", 1985, "Hong Kong", "Z80"),
#  Product(145, "Vector-06C", "Vector", 1987, "USSR", "8080 compatible"),
#  Product(52, "Video Genie", "EACA", 1980, "Hong Kong", "Z80"),
#  Product(146, "VideoBrain Family Computer", "Videobrain", 1977, "USA", "Fairchild F8"),
#  Product(148, "West PC-800", "West Computer AS", 1984, "Norway", "6502, Z80"),
#  Product(120, "Z1013", "VEB Robotron", 1985, "East Germany", "Z80 compatible"),
#  Product(127, "ZX Spectrum", "Sinclair Research", 1982, "UK", "Z80"),
#  Product(125, "ZX80", "Sinclair Research", 1980, "UK", "Z80"),
#  Product(126, "ZX81", "Sinclair Research", 1981, "UK", "Z80")]

# %%
q = select(Product).order_by(Product.year.desc())
session.scalars(q).all()
# Out:
# [Product(6, "A7000", "Acorn Computers Ltd", 1995, "UK", "ARM RISC"),
#  Product(33, "Falcon", "Atari Corporation", 1992, "USA", "68030 + 56001"),
#  Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),
#  Product(79, "Hobbit", "Intercompex", 1990, "USSR", "Z80 compatible"),
#  Product(76, "IBM PS/1", "IBM", 1990, "USA", "8088"),
#  Product(32, "Atari TT", "Atari Corporation", 1990, "USA", "68030"),
#  Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),
#  Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),
#  Product(135, "MAŤO", "Štátny majetok Závadka š.p.", 1989, "Czechoslovakia", "8080"),
#  Product(93, "SAM Coupé", "Miles Gordon Technology", 1989, "UK", "Z80"),
#  Product(80, "Iskra-1030", "Iskra", 1989, "USSR", "8086 compatible"),
#  Product(70, "FM Towns", "Fujitsu", 1989, "Japan", "80386SX"),
#  Product(104, "Euro PC", "Schneider Computer Division", 1988, "Germany", "8088"),
#  Product(19, "Apple IIc Plus", "Apple Computer", 1988, "USA", "65C02"),
#  Product(145, "Vector-06C", "Vector", 1987, "USSR", "8080 compatible"),
#  Product(124, "Sharp X68000", "Sharp", 1987, "Japan", "68000"),
#  Product(119, "KC 87", "VEB Robotron", 1987, "East Germany", "Z80 compatible"),
#  Product(103, "Tandy 1000", "Radio Shack", 1987, "USA", "8088"),
#  Product(57, "Gama", "Didaktik", 1987, "Czechoslovakia", "Z80"),
#  Product(5, "Acorn Archimedes", "Acorn Computers Ltd", 1987, "UK", "ARM RISC"),
#  Product(147, "TVC", "Videoton", 1986, "Hungary", "Z80"),
#  Product(144, "Tomy Tutor", "Tomy", 1986, "Japan", "TMS 9900"),
#  Product(143, "Komputer 2086", "Timex Sinclair", 1986, "Portugal/Poland", "Z80"),
#  Product(107, "Oric Telestrat", "Tangerine Computer Systems", 1986, "UK", "6502"),
#  Product(56, "Beta", "Didaktik", 1986, "Czechoslovakia", "Z80"),
#  Product(55, "Alpha", "Didaktik", 1986, "Czechoslovakia", "Z80"),
#  Product(36, "CoBra", "Brasov Computer", 1986, "Romania", "Z80"),
#  Product(21, "Apple IIGS", "Apple Computer", 1986, "USA", "65C816"),
#  Product(14, "CEC-I Zhonghua", "Tsinghua University", 1986, "China", "6502"),
#  Product(13, "PC-1512", "Amstrad", 1986, "UK", "8086"),
#  Product(4, "BBC Master", "Acorn Computers Ltd", 1986, "UK", "65SC12"),
#  Product(149, "GEM 1000", "GEM", 1985, "Belgium", "Z80"),
#  Product(134, "PMD 85", "Tesla", 1985, "Czechoslovakia", "8080"),
#  Product(120, "Z1013", "VEB Robotron", 1985, "East Germany", "Z80 compatible"),
#  Product(113, "Pravetz 8", "Pravetz", 1985, "Bulgaria", "CM630 (6502 clone)"),
#  Product(112, "Philips :YES", "Philips", 1985, "Netherlands", "80186"),
#  Product(92, "TK82C", "Microdigital Eletronica", 1985, "Brazil", "Z80"),
#  Product(91, "CCE MC-1000", "Comércio de Componentes Eletrônicos", 1985, "Brazil", "Z80"),
#  Product(73, "Gradiente Expert", "Gradiente", 1985, "Brazil", "Z80"),
#  Product(68, "Lambda 8300", "Lambda Electronics", 1985, "Hong Kong", "Z80"),
#  Product(67, "Enterprise 128", "Intelligent Software", 1985, "UK", "Z80"),
#  Product(66, "Enterprise 64", "Intelligent Software", 1985, "UK", "Z80"),
#  Product(64, "Pecom 64", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),
#  Product(63, "Pecom 32", "Elektronska Industrija Niš", 1985, "Serbia", "RCA 1802"),
#  Product(61, "BK-0010", "Elektronika", 1985, "USSR", "PDP 11 (compatible)"),
#  Product(51, "VTech Laser 200", "Vtech", 1985, "Hong Kong", "Z80"),
#  Product(48, "Amiga", "Commodore", 1985, "USA", "68000 (family)"),
#  Product(47, "Commodore 128", "Commodore", 1985, "USA", "8502 (6502) / Z80"),
#  Product(31, "Atari ST", "Atari Corporation", 1985, "USA", "68000"),
#  Product(30, "Atari 130XE", "Atari, Inc.", 1985, "USA", "6502C"),
#  Product(29, "Atari 65XE", "Atari, Inc.", 1985, "USA", "6502C"),
#  Product(12, "PCW", "Amstrad", 1985, "UK", "Z80"),
#  Product(148, "West PC-800", "West Computer AS", 1984, "Norway", "6502, Z80"),
#  Product(141, "Timex Computer 2048", "Timex Sinclair", 1984, "Portugal", "Z80"),
#  Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80"),
#  Product(137, "MO5", "Thomson", 1984, "France", "6809"),
#  Product(131, "Aamber Pegasus", "Technosys", 1984, "New Zealand", "6809"),
#  Product(128, "Sinclair QL", "Sinclair Research", 1984, "UK", "68008"),
#  Product(118, "KC 85", "VEB Robotron", 1984, "East Germany", "Z80 compatible"),
#  Product(117, "Prológica CP-400", "Prológica", 1984, "Brazil", "6809"),
#  Product(109, "Orao", "PEL Varaždin", 1984, "Croatia", "6502"),
#  Product(106, "Oric Atmos", "Tangerine Computer Systems", 1984, "UK", "6502"),
#  Product(81, "Ivel Ultra", "Ivasim", 1984, "Croatia", "6502 compatible"),
#  Product(75, "PCjr", "IBM", 1984, "USA", "8088"),
#  Product(62, "AGAT-9", "AGAT", 1984, "USSR", "Native/Apple II compatible"),
#  Product(46, "Plus/4", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(45, "Commodore 116", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(44, "Commodore 16", "Commodore", 1984, "USA", "8501 (6502)"),
#  Product(22, "Apricot F1", "Apricot Computers", 1984, "UK", "8088"),
#  Product(18, "Apple IIc", "Apple Computer", 1984, "USA", "65C02"),
#  Product(9, "CPC 6128", "Amstrad", 1984, "UK", "Z80"),
#  Product(8, "CPC 664", "Amstrad", 1984, "UK", "Z80"),
#  Product(7, "CPC 464", "Amstrad", 1984, "UK", "Z80"),
#  Product(142, "Timex Computer 2068", "Timex Sinclair", 1983, "USA/UK/Portugal", "Z80"),
#  Product(121, "SC-3000", "Sega", 1983, "Japan", "Z80 compatible"),
#  Product(111, "G7480", "Philips", 1983, "Netherlands", "Z80"),
#  Product(105, "Oric 1", "Tangerine Computer Systems", 1983, "UK", "6502"),
#  Product(102, "TRS-80 MC-10", "Radio Shack", 1983, "USA", "6803"),
#  Product(95, "NEC PC-100", "NEC", 1983, "Japan", "8086"),
#  Product(94, "Microprofessor III", "Multitech", 1983, "Taiwan", "6502"),
#  Product(90, "MicroBee", "Microbee Systems", 1983, "Australia", "Z80"),
#  Product(89, "RS128", "Memotech", 1983, "UK", "Z80"),
#  Product(88, "MTX512", "Memotech", 1983, "UK", "Z80"),
#  Product(87, "MTX500", "Memotech", 1983, "UK", "Z80"),
#  Product(86, "Matra Alice", "Matra", 1983, "France", "6803"),
#  Product(85, "Aquarius", "Mattel", 1983, "USA", "Z80"),
#  Product(82, "Ivel Z3", "Ivasim", 1983, "Croatia", "6502 compatible"),
#  Product(54, "Rabbit RX83", "Rabbit", 1983, "Hong Kong", "Z80"),
#  Product(53, "Colour Genie", "EACA", 1983, "Hong Kong", "Z80"),
#  Product(49, "Comx-35", "Comx World Operations", 1983, "Hong Kong", "RCA 1802"),
#  Product(38, "Coleco Adam", "Coleco", 1983, "USA", "Z80"),
#  Product(37, "Lynx", "Camputers", 1983, "UK", "Z80"),
#  Product(28, "Atari 800XL", "Atari, Inc.", 1983, "USA", "6502"),
#  Product(27, "Atari 600XL", "Atari, Inc.", 1983, "USA", "6502"),
#  Product(26, "Atari 1200XL", "Atari, Inc.", 1983, "USA", "6502"),
#  Product(17, "Apple IIe", "Apple Computer", 1983, "USA", "6502"),
#  Product(3, "Electron", "Acorn Computers Ltd", 1983, "UK", "6502"),
#  Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),
#  Product(136, "TO7", "Thomson", 1982, "France", "6809"),
#  Product(130, "Sord M5", "Sord Computer Corporation", 1982, "Japan", "Z80"),
#  Product(127, "ZX Spectrum", "Sinclair Research", 1982, "UK", "Z80"),
#  Product(123, "Sharp X1", "Sharp", 1982, "Japan", "Z80 compatible"),
#  Product(114, "Pravetz 8D", "Pravetz", 1982, "Bulgaria", "6502"),
#  Product(83, "Jupiter ACE", "Jupiter Cantab", 1982, "UK", "Z80"),
#  Product(72, "Grundy NewBrain", "Grundy Business Systems", 1982, "UK", "Z80"),
#  Product(71, "FM-7", "Fujitsu", 1982, "Japan", "6809"),
#  Product(69, "Franklin ACE", "Franklin Computer Corporation", 1982, "USA", "6502"),
#  Product(59, "Dragon 64", "Dragon Data", 1982, "UK", "6809"),
#  Product(58, "Dragon 32", "Dragon Data", 1982, "UK", "6809"),
#  Product(43, "MAX Machine", "Commodore", 1982, "USA", "6510"),
#  Product(42, "Commodore Executive 64", "Commodore", 1982, "USA", "6510"),
#  Product(41, "Commodore 64", "Commodore", 1982, "USA", "6510"),
#  Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80"),
#  Product(126, "ZX81", "Sinclair Research", 1981, "UK", "Z80"),
#  Product(116, "Poly-1", "Progeni Systems / Polycorp", 1981, "New Zealand", "6809"),
#  Product(108, "Galeb", "PEL Varaždin", 1981, "Croatia", "6502"),
#  Product(97, "PC-8800", "NEC", 1981, "Japan", "Z80"),
#  Product(96, "PC-6000", "NEC Home Electronics", 1981, "Japan", "Z80"),
#  Product(2, "BBC Micro", "Acorn Computers Ltd", 1981, "UK", "6502"),
#  Product(125, "ZX80", "Sinclair Research", 1980, "UK", "Z80"),
#  Product(115, "IMKO-1", "Pravetz", 1980, "Bulgaria", "6502"),
#  Product(110, "P2000", "Philips", 1980, "Netherlands", "Z80"),
#  Product(100, "TRS-80 Color Computer 3", "Radio Shack", 1980, "USA", "6809"),
#  Product(99, "TRS-80 Color Computer 2", "Radio Shack", 1980, "USA", "6809"),
#  Product(98, "TRS-80 Color Computer", "Radio Shack", 1980, "USA", "6809"),
#  Product(52, "Video Genie", "EACA", 1980, "Hong Kong", "Z80"),
#  Product(50, "DAI Personal Computer", "Data Applications International", 1980, "Belgium", "8080"),
#  Product(40, "VIC-20", "Commodore", 1980, "USA", "6502"),
#  Product(1, "Acorn Atom", "Acorn Computers Ltd", 1980, "UK", "6502"),
#  Product(133, "TI-99/4A", "Texas Instruments", 1979, "USA", "TMS 9900"),
#  Product(132, "TI-99/4", "Texas Instruments", 1979, "USA", "TMS 9900"),
#  Product(122, "MZ", "Sharp", 1979, "Japan", "Z80 compatible"),
#  Product(77, "Interact Home Computer", "Interact", 1979, "USA", "8080"),
#  Product(34, "Bally Brain", "Bally Consumer Products", 1979, "USA", "Z80"),
#  Product(25, "Atari 800", "Atari, Inc.", 1979, "USA", "6502"),
#  Product(24, "Atari 400", "Atari, Inc.", 1979, "USA", "6502"),
#  Product(20, "Apple II Plus", "Apple Computer", 1979, "USA", "6502"),
#  Product(15, "Imagination Machine", "APF Electronics, Inc.", 1979, "USA", "6800"),
#  Product(84, "ABC 80", "Luxor", 1978, "Sweden", "Z80"),
#  Product(65, "Exidy Sorcerer", "Exidy", 1978, "USA", "Z80"),
#  Product(146, "VideoBrain Family Computer", "Videobrain", 1977, "USA", "Fairchild F8"),
#  Product(129, "Sord M200 Smart Home Computer", "Sord Computer Corporation", 1977, "Japan", "Z80"),
#  Product(101, "TRS-80 Model I", "Radio Shack", 1977, "USA", "Z80"),
#  Product(78, "Compucolor II", "Intelligent Systems Corporation", 1977, "USA", "8080"),
#  Product(39, "PET", "Commodore", 1977, "USA", "6502"),
#  Product(35, "Bally Astrocade", "Bally Consumer Products", 1977, "USA", "Z80"),
#  Product(16, "Apple II", "Apple Computer", 1977, "USA", "6502"),
#  Product(74, "Honeywell 316", "Honeywell", 1969, "USA", "DDP 16 Minicomputer")]

# %%
q = select(Product).order_by(Product.year.desc(), Product.name.asc())
results = session.scalars(q).all()

# %%
results[10]
# Out:
# Product(135, "MAŤO", "Štátny majetok Závadka š.p.", 1989, "Czechoslovakia", "8080")

# %%
q = select(Product.name)
session.scalars(q).all()
# Out:
# ['464 Plus',
#  '6128 Plus',
#  'A7000',
#  'ABC 80',
#  'AGAT-9',
#  'Aamber Pegasus',
#  'Acorn Archimedes',
#  'Acorn Atom',
#  'Alpha',
#  'Amiga',
#  'Apple II',
#  'Apple II Plus',
#  'Apple IIGS',
#  'Apple IIc',
#  'Apple IIc Plus',
#  'Apple IIe',
#  'Apricot F1',
#  'Aquarius',
#  'Atari 1200XL',
#  'Atari 130XE',
#  'Atari 400',
#  'Atari 600XL',
#  'Atari 65XE',
#  'Atari 800',
#  'Atari 800XL',
#  'Atari ST',
#  'Atari TT',
#  'BBC Master',
#  'BBC Micro',
#  'BK-0010',
#  'Bally Astrocade',
#  'Bally Brain',
#  'Beta',
#  'CCE MC-1000',
#  'CEC-I Zhonghua',
#  'CPC 464',
#  'CPC 6128',
#  'CPC 664',
#  'CT-80',
#  'CoBra',
#  'Coleco Adam',
#  'Colour Genie',
#  'Commodore 116',
#  'Commodore 128',
#  'Commodore 16',
#  'Commodore 64',
#  'Commodore Executive 64',
#  'Compucolor II',
#  'Comx-35',
#  'DAI Personal Computer',
#  'Dragon 32',
#  'Dragon 64',
#  'Dubna 48K',
#  'Electron',
#  'Enterprise 128',
#  'Enterprise 64',
#  'Euro PC',
#  'Exidy Sorcerer',
#  'FM Towns',
#  'FM-7',
#  'Falcon',
#  'Franklin ACE',
#  'G7480',
#  'GEM 1000',
#  'Galeb',
#  'Gama',
#  'Gradiente Expert',
#  'Grundy NewBrain',
#  'Hobbit',
#  'Honeywell 316',
#  'IBM PS/1',
#  'IMKO-1',
#  'Imagination Machine',
#  'Interact Home Computer',
#  'Iskra-1030',
#  'Ivel Ultra',
#  'Ivel Z3',
#  'Jupiter ACE',
#  'KC 85',
#  'KC 87',
#  'Komputer 2086',
#  'Lambda 8300',
#  'Lynx',
#  'MAX Machine',
#  'MAŤO',
#  'MO5',
#  'MTX500',
#  'MTX512',
#  'MZ',
#  'Matra Alice',
#  'MicroBee',
#  'Microprofessor III',
#  'NEC PC-100',
#  'Orao',
#  'Oric 1',
#  'Oric Atmos',
#  'Oric Telestrat',
#  'P2000',
#  'PC-1512',
#  'PC-6000',
#  'PC-8800',
#  'PCW',
#  'PCjr',
#  'PET',
#  'PMD 85',
#  'Pecom 32',
#  'Pecom 64',
#  'Philips :YES',
#  'Plus/4',
#  'Poly-1',
#  'Pravetz 8',
#  'Pravetz 8D',
#  'Prológica CP-400',
#  'RS128',
#  'Rabbit RX83',
#  'SAM Coupé',
#  'SC-3000',
#  'Sharp X1',
#  'Sharp X68000',
#  'Sinclair QL',
#  'Sord M200 Smart Home Computer',
#  'Sord M5',
#  'TI-99/4',
#  'TI-99/4A',
#  'TK82C',
#  'TO7',
#  'TRS-80 Color Computer',
#  'TRS-80 Color Computer 2',
#  'TRS-80 Color Computer 3',
#  'TRS-80 MC-10',
#  'TRS-80 Model I',
#  'TVC',
#  'Tandy 1000',
#  'Timex Computer 2048',
#  'Timex Computer 2068',
#  'Timex Sinclair 1000',
#  'Timex Sinclair 1500',
#  'Timex Sinclair 2048',
#  'Tomy Tutor',
#  'VIC-20',
#  'VTech Laser 200',
#  'Vector-06C',
#  'Video Genie',
#  'VideoBrain Family Computer',
#  'West PC-800',
#  'Z1013',
#  'ZX Spectrum',
#  'ZX80',
#  'ZX81']

# %%
q = select(Product.name, Product.manufacturer)
session.execute(q).all()
# Out:
# [('Acorn Atom', 'Acorn Computers Ltd'),
#  ('BBC Micro', 'Acorn Computers Ltd'),
#  ('Electron', 'Acorn Computers Ltd'),
#  ('BBC Master', 'Acorn Computers Ltd'),
#  ('Acorn Archimedes', 'Acorn Computers Ltd'),
#  ('A7000', 'Acorn Computers Ltd'),
#  ('CPC 464', 'Amstrad'),
#  ('CPC 664', 'Amstrad'),
#  ('CPC 6128', 'Amstrad'),
#  ('464 Plus', 'Amstrad'),
#  ('6128 Plus', 'Amstrad'),
#  ('PCW', 'Amstrad'),
#  ('PC-1512', 'Amstrad'),
#  ('CEC-I Zhonghua', 'Tsinghua University'),
#  ('Imagination Machine', 'APF Electronics, Inc.'),
#  ('Apple II', 'Apple Computer'),
#  ('Apple IIe', 'Apple Computer'),
#  ('Apple IIc', 'Apple Computer'),
#  ('Apple IIc Plus', 'Apple Computer'),
#  ('Apple II Plus', 'Apple Computer'),
#  ('Apple IIGS', 'Apple Computer'),
#  ('Apricot F1', 'Apricot Computers'),
#  ('CT-80', 'Aster Computers'),
#  ('Atari 400', 'Atari, Inc.'),
#  ('Atari 800', 'Atari, Inc.'),
#  ('Atari 1200XL', 'Atari, Inc.'),
#  ('Atari 600XL', 'Atari, Inc.'),
#  ('Atari 800XL', 'Atari, Inc.'),
#  ('Atari 65XE', 'Atari, Inc.'),
#  ('Atari 130XE', 'Atari, Inc.'),
#  ('Atari ST', 'Atari Corporation'),
#  ('Atari TT', 'Atari Corporation'),
#  ('Falcon', 'Atari Corporation'),
#  ('Bally Brain', 'Bally Consumer Products'),
#  ('Bally Astrocade', 'Bally Consumer Products'),
#  ('CoBra', 'Brasov Computer'),
#  ('Lynx', 'Camputers'),
#  ('Coleco Adam', 'Coleco'),
#  ('PET', 'Commodore'),
#  ('VIC-20', 'Commodore'),
#  ('Commodore 64', 'Commodore'),
#  ('Commodore Executive 64', 'Commodore'),
#  ('MAX Machine', 'Commodore'),
#  ('Commodore 16', 'Commodore'),
#  ('Commodore 116', 'Commodore'),
#  ('Plus/4', 'Commodore'),
#  ('Commodore 128', 'Commodore'),
#  ('Amiga', 'Commodore'),
#  ('Comx-35', 'Comx World Operations'),
#  ('DAI Personal Computer', 'Data Applications International'),
#  ('VTech Laser 200', 'Vtech'),
#  ('Video Genie', 'EACA'),
#  ('Colour Genie', 'EACA'),
#  ('Rabbit RX83', 'Rabbit'),
#  ('Alpha', 'Didaktik'),
#  ('Beta', 'Didaktik'),
#  ('Gama', 'Didaktik'),
#  ('Dragon 32', 'Dragon Data'),
#  ('Dragon 64', 'Dragon Data'),
#  ('Dubna 48K', 'Dubna'),
#  ('BK-0010', 'Elektronika'),
#  ('AGAT-9', 'AGAT'),
#  ('Pecom 32', 'Elektronska Industrija Niš'),
#  ('Pecom 64', 'Elektronska Industrija Niš'),
#  ('Exidy Sorcerer', 'Exidy'),
#  ('Enterprise 64', 'Intelligent Software'),
#  ('Enterprise 128', 'Intelligent Software'),
#  ('Lambda 8300', 'Lambda Electronics'),
#  ('Franklin ACE', 'Franklin Computer Corporation'),
#  ('FM Towns', 'Fujitsu'),
#  ('FM-7', 'Fujitsu'),
#  ('Grundy NewBrain', 'Grundy Business Systems'),
#  ('Gradiente Expert', 'Gradiente'),
#  ('Honeywell 316', 'Honeywell'),
#  ('PCjr', 'IBM'),
#  ('IBM PS/1', 'IBM'),
#  ('Interact Home Computer', 'Interact'),
#  ('Compucolor II', 'Intelligent Systems Corporation'),
#  ('Hobbit', 'Intercompex'),
#  ('Iskra-1030', 'Iskra'),
#  ('Ivel Ultra', 'Ivasim'),
#  ('Ivel Z3', 'Ivasim'),
#  ('Jupiter ACE', 'Jupiter Cantab'),
#  ('ABC 80', 'Luxor'),
#  ('Aquarius', 'Mattel'),
#  ('Matra Alice', 'Matra'),
#  ('MTX500', 'Memotech'),
#  ('MTX512', 'Memotech'),
#  ('RS128', 'Memotech'),
#  ('MicroBee', 'Microbee Systems'),
#  ('CCE MC-1000', 'Comércio de Componentes Eletrônicos'),
#  ('TK82C', 'Microdigital Eletronica'),
#  ('SAM Coupé', 'Miles Gordon Technology'),
#  ('Microprofessor III', 'Multitech'),
#  ('NEC PC-100', 'NEC'),
#  ('PC-6000', 'NEC Home Electronics'),
#  ('PC-8800', 'NEC'),
#  ('TRS-80 Color Computer', 'Radio Shack'),
#  ('TRS-80 Color Computer 2', 'Radio Shack'),
#  ('TRS-80 Color Computer 3', 'Radio Shack'),
#  ('TRS-80 Model I', 'Radio Shack'),
#  ('TRS-80 MC-10', 'Radio Shack'),
#  ('Tandy 1000', 'Radio Shack'),
#  ('Euro PC', 'Schneider Computer Division'),
#  ('Oric 1', 'Tangerine Computer Systems'),
#  ('Oric Atmos', 'Tangerine Computer Systems'),
#  ('Oric Telestrat', 'Tangerine Computer Systems'),
#  ('Galeb', 'PEL Varaždin'),
#  ('Orao', 'PEL Varaždin'),
#  ('P2000', 'Philips'),
#  ('G7480', 'Philips'),
#  ('Philips :YES', 'Philips'),
#  ('Pravetz 8', 'Pravetz'),
#  ('Pravetz 8D', 'Pravetz'),
#  ('IMKO-1', 'Pravetz'),
#  ('Poly-1', 'Progeni Systems / Polycorp'),
#  ('Prológica CP-400', 'Prológica'),
#  ('KC 85', 'VEB Robotron'),
#  ('KC 87', 'VEB Robotron'),
#  ('Z1013', 'VEB Robotron'),
#  ('SC-3000', 'Sega'),
#  ('MZ', 'Sharp'),
#  ('Sharp X1', 'Sharp'),
#  ('Sharp X68000', 'Sharp'),
#  ('ZX80', 'Sinclair Research'),
#  ('ZX81', 'Sinclair Research'),
#  ('ZX Spectrum', 'Sinclair Research'),
#  ('Sinclair QL', 'Sinclair Research'),
#  ('Sord M200 Smart Home Computer', 'Sord Computer Corporation'),
#  ('Sord M5', 'Sord Computer Corporation'),
#  ('Aamber Pegasus', 'Technosys'),
#  ('TI-99/4', 'Texas Instruments'),
#  ('TI-99/4A', 'Texas Instruments'),
#  ('PMD 85', 'Tesla'),
#  ('MAŤO', 'Štátny majetok Závadka š.p.'),
#  ('TO7', 'Thomson'),
#  ('MO5', 'Thomson'),
#  ('Timex Sinclair 1000', 'Timex Sinclair'),
#  ('Timex Sinclair 1500', 'Timex Sinclair'),
#  ('Timex Sinclair 2048', 'Timex Sinclair'),
#  ('Timex Computer 2048', 'Timex Sinclair'),
#  ('Timex Computer 2068', 'Timex Sinclair'),
#  ('Komputer 2086', 'Timex Sinclair'),
#  ('Tomy Tutor', 'Tomy'),
#  ('Vector-06C', 'Vector'),
#  ('VideoBrain Family Computer', 'Videobrain'),
#  ('TVC', 'Videoton'),
#  ('West PC-800', 'West Computer AS'),
#  ('GEM 1000', 'GEM')]

# %%
from sqlalchemy import func
q = select(func.count(Product.id))
r = session.scalar(q)
r
# Out:
# 149

# %%
q = select(func.count()).select_from(Product)
r = session.scalar(q)
r
# Out:
# 149

# %%
q = select(func.min(Product.year), func.max(Product.year))
r = session.execute(q)
r.first()
# Out:
# (1969, 1995)

# %%
q = select(Product.manufacturer).order_by(Product.manufacturer)
session.scalars(q).all()
# Out:
# ['AGAT',
#  'APF Electronics, Inc.',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Acorn Computers Ltd',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Amstrad',
#  'Apple Computer',
#  'Apple Computer',
#  'Apple Computer',
#  'Apple Computer',
#  'Apple Computer',
#  'Apple Computer',
#  'Apricot Computers',
#  'Aster Computers',
#  'Atari Corporation',
#  'Atari Corporation',
#  'Atari Corporation',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Atari, Inc.',
#  'Bally Consumer Products',
#  'Bally Consumer Products',
#  'Brasov Computer',
#  'Camputers',
#  'Coleco',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Commodore',
#  'Comx World Operations',
#  'Comércio de Componentes Eletrônicos',
#  'Data Applications International',
#  'Didaktik',
#  'Didaktik',
#  'Didaktik',
#  'Dragon Data',
#  'Dragon Data',
#  'Dubna',
#  'EACA',
#  'EACA',
#  'Elektronika',
#  'Elektronska Industrija Niš',
#  'Elektronska Industrija Niš',
#  'Exidy',
#  'Franklin Computer Corporation',
#  'Fujitsu',
#  'Fujitsu',
#  'GEM',
#  'Gradiente',
#  'Grundy Business Systems',
#  'Honeywell',
#  'IBM',
#  'IBM',
#  'Intelligent Software',
#  'Intelligent Software',
#  'Intelligent Systems Corporation',
#  'Interact',
#  'Intercompex',
#  'Iskra',
#  'Ivasim',
#  'Ivasim',
#  'Jupiter Cantab',
#  'Lambda Electronics',
#  'Luxor',
#  'Matra',
#  'Mattel',
#  'Memotech',
#  'Memotech',
#  'Memotech',
#  'Microbee Systems',
#  'Microdigital Eletronica',
#  'Miles Gordon Technology',
#  'Multitech',
#  'NEC',
#  'NEC',
#  'NEC Home Electronics',
#  'PEL Varaždin',
#  'PEL Varaždin',
#  'Philips',
#  'Philips',
#  'Philips',
#  'Pravetz',
#  'Pravetz',
#  'Pravetz',
#  'Progeni Systems / Polycorp',
#  'Prológica',
#  'Rabbit',
#  'Radio Shack',
#  'Radio Shack',
#  'Radio Shack',
#  'Radio Shack',
#  'Radio Shack',
#  'Radio Shack',
#  'Schneider Computer Division',
#  'Sega',
#  'Sharp',
#  'Sharp',
#  'Sharp',
#  'Sinclair Research',
#  'Sinclair Research',
#  'Sinclair Research',
#  'Sinclair Research',
#  'Sord Computer Corporation',
#  'Sord Computer Corporation',
#  'Tangerine Computer Systems',
#  'Tangerine Computer Systems',
#  'Tangerine Computer Systems',
#  'Technosys',
#  'Tesla',
#  'Texas Instruments',
#  'Texas Instruments',
#  'Thomson',
#  'Thomson',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Timex Sinclair',
#  'Tomy',
#  'Tsinghua University',
#  'VEB Robotron',
#  'VEB Robotron',
#  'VEB Robotron',
#  'Vector',
#  'Videobrain',
#  'Videoton',
#  'Vtech',
#  'West Computer AS',
#  'Štátny majetok Závadka š.p.']

# %% [markdown]
# Whenever a database query can return duplicated results, the distinct() clause added to it tells the database to combine identical results:

# %%
q = select(Product.manufacturer).order_by(Product.manufacturer).distinct()
session.scalars(q).all()
# Out:
# ['AGAT',
#  'APF Electronics, Inc.',
#  'Acorn Computers Ltd',
#  'Amstrad',
#  'Apple Computer',
#  'Apricot Computers',
#  'Aster Computers',
#  'Atari Corporation',
#  'Atari, Inc.',
#  'Bally Consumer Products',
#  'Brasov Computer',
#  'Camputers',
#  'Coleco',
#  'Commodore',
#  'Comx World Operations',
#  'Comércio de Componentes Eletrônicos',
#  'Data Applications International',
#  'Didaktik',
#  'Dragon Data',
#  'Dubna',
#  'EACA',
#  'Elektronika',
#  'Elektronska Industrija Niš',
#  'Exidy',
#  'Franklin Computer Corporation',
#  'Fujitsu',
#  'GEM',
#  'Gradiente',
#  'Grundy Business Systems',
#  'Honeywell',
#  'IBM',
#  'Intelligent Software',
#  'Intelligent Systems Corporation',
#  'Interact',
#  'Intercompex',
#  'Iskra',
#  'Ivasim',
#  'Jupiter Cantab',
#  'Lambda Electronics',
#  'Luxor',
#  'Matra',
#  'Mattel',
#  'Memotech',
#  'Microbee Systems',
#  'Microdigital Eletronica',
#  'Miles Gordon Technology',
#  'Multitech',
#  'NEC',
#  'NEC Home Electronics',
#  'PEL Varaždin',
#  'Philips',
#  'Pravetz',
#  'Progeni Systems / Polycorp',
#  'Prológica',
#  'Rabbit',
#  'Radio Shack',
#  'Schneider Computer Division',
#  'Sega',
#  'Sharp',
#  'Sinclair Research',
#  'Sord Computer Corporation',
#  'Tangerine Computer Systems',
#  'Technosys',
#  'Tesla',
#  'Texas Instruments',
#  'Thomson',
#  'Timex Sinclair',
#  'Tomy',
#  'Tsinghua University',
#  'VEB Robotron',
#  'Vector',
#  'Videobrain',
#  'Videoton',
#  'Vtech',
#  'West Computer AS',
#  'Štátny majetok Závadka š.p.']

# %%
q = select(func.count(Product.manufacturer.distinct()))
session.scalar(q)
# Out:
# 76

# %%
q = (select(Product.manufacturer)
     .group_by(Product.manufacturer)
     .order_by(Product.manufacturer))

# %%
q = (select(
    Product.manufacturer,
    func.min(Product.year),
    func.max(Product.year),
    func.count()
)
.group_by(Product.manufacturer)
.order_by(Product.manufacturer)
)
session.execute(q).all()
# Out:
# [('AGAT', 1984, 1984, 1),
#  ('APF Electronics, Inc.', 1979, 1979, 1),
#  ('Acorn Computers Ltd', 1980, 1995, 6),
#  ('Amstrad', 1984, 1990, 7),
#  ('Apple Computer', 1977, 1988, 6),
#  ('Apricot Computers', 1984, 1984, 1),
#  ('Aster Computers', 1982, 1982, 1),
#  ('Atari Corporation', 1985, 1992, 3),
#  ('Atari, Inc.', 1979, 1985, 7),
#  ('Bally Consumer Products', 1977, 1979, 2),
#  ('Brasov Computer', 1986, 1986, 1),
#  ('Camputers', 1983, 1983, 1),
#  ('Coleco', 1983, 1983, 1),
#  ('Commodore', 1977, 1985, 10),
#  ('Comx World Operations', 1983, 1983, 1),
#  ('Comércio de Componentes Eletrônicos', 1985, 1985, 1),
#  ('Data Applications International', 1980, 1980, 1),
#  ('Didaktik', 1986, 1987, 3),
#  ('Dragon Data', 1982, 1982, 2),
#  ('Dubna', 1991, 1991, 1),
#  ('EACA', 1980, 1983, 2),
#  ('Elektronika', 1985, 1985, 1),
#  ('Elektronska Industrija Niš', 1985, 1985, 2),
#  ('Exidy', 1978, 1978, 1),
#  ('Franklin Computer Corporation', 1982, 1982, 1),
#  ('Fujitsu', 1982, 1989, 2),
#  ('GEM', 1985, 1985, 1),
#  ('Gradiente', 1985, 1985, 1),
#  ('Grundy Business Systems', 1982, 1982, 1),
#  ('Honeywell', 1969, 1969, 1),
#  ('IBM', 1984, 1990, 2),
#  ('Intelligent Software', 1985, 1985, 2),
#  ('Intelligent Systems Corporation', 1977, 1977, 1),
#  ('Interact', 1979, 1979, 1),
#  ('Intercompex', 1990, 1990, 1),
#  ('Iskra', 1989, 1989, 1),
#  ('Ivasim', 1983, 1984, 2),
#  ('Jupiter Cantab', 1982, 1982, 1),
#  ('Lambda Electronics', 1985, 1985, 1),
#  ('Luxor', 1978, 1978, 1),
#  ('Matra', 1983, 1983, 1),
#  ('Mattel', 1983, 1983, 1),
#  ('Memotech', 1983, 1983, 3),
#  ('Microbee Systems', 1983, 1983, 1),
#  ('Microdigital Eletronica', 1985, 1985, 1),
#  ('Miles Gordon Technology', 1989, 1989, 1),
#  ('Multitech', 1983, 1983, 1),
#  ('NEC', 1981, 1983, 2),
#  ('NEC Home Electronics', 1981, 1981, 1),
#  ('PEL Varaždin', 1981, 1984, 2),
#  ('Philips', 1980, 1985, 3),
#  ('Pravetz', 1980, 1985, 3),
#  ('Progeni Systems / Polycorp', 1981, 1981, 1),
#  ('Prológica', 1984, 1984, 1),
#  ('Rabbit', 1983, 1983, 1),
#  ('Radio Shack', 1977, 1987, 6),
#  ('Schneider Computer Division', 1988, 1988, 1),
#  ('Sega', 1983, 1983, 1),
#  ('Sharp', 1979, 1987, 3),
#  ('Sinclair Research', 1980, 1984, 4),
#  ('Sord Computer Corporation', 1977, 1982, 2),
#  ('Tangerine Computer Systems', 1983, 1986, 3),
#  ('Technosys', 1984, 1984, 1),
#  ('Tesla', 1985, 1985, 1),
#  ('Texas Instruments', 1979, 1979, 2),
#  ('Thomson', 1982, 1984, 2),
#  ('Timex Sinclair', 1982, 1986, 6),
#  ('Tomy', 1986, 1986, 1),
#  ('Tsinghua University', 1986, 1986, 1),
#  ('VEB Robotron', 1984, 1987, 3),
#  ('Vector', 1987, 1987, 1),
#  ('Videobrain', 1977, 1977, 1),
#  ('Videoton', 1986, 1986, 1),
#  ('Vtech', 1985, 1985, 1),
#  ('West Computer AS', 1984, 1984, 1),
#  ('Štátny majetok Závadka š.p.', 1989, 1989, 1)]

# %%
q = (select(
    Product.manufacturer,
    func.count()
)
.group_by(Product.manufacturer)
.having(func.count() >= 5)
.order_by(Product.manufacturer)
)

session.execute(q).all()
# Out:
# [('Acorn Computers Ltd', 6),
#  ('Amstrad', 7),
#  ('Apple Computer', 6),
#  ('Atari, Inc.', 7),
#  ('Commodore', 10),
#  ('Radio Shack', 6),
#  ('Timex Sinclair', 6)]

# %%
num_products = func.count().label(None)
q = (select(
    Product.manufacturer,
    num_products
)
.group_by(Product.manufacturer)
.having(num_products >= 5)
.order_by(num_products.desc())
)

session.execute(q).all()
# Out:
# [('Commodore', 10),
#  ('Amstrad', 7),
#  ('Atari, Inc.', 7),
#  ('Acorn Computers Ltd', 6),
#  ('Apple Computer', 6),
#  ('Radio Shack', 6),
#  ('Timex Sinclair', 6)]

# %%
num_products = func.count().label('num_products')
q = (select(
    Product.manufacturer,
    num_products
)
.group_by(Product.manufacturer)
.having(num_products >= 5)
.order_by(num_products.desc())
)

session.execute(q).all()
# Out:
# [('Commodore', 10),
#  ('Amstrad', 7),
#  ('Atari, Inc.', 7),
#  ('Acorn Computers Ltd', 6),
#  ('Apple Computer', 6),
#  ('Radio Shack', 6),
#  ('Timex Sinclair', 6)]

# %%
q = select(Product).order_by(Product.name).limit(3)
session.execute(q).all()
# Out:
# [(Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),),
#  (Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),),
#  (Product(6, "A7000", "Acorn Computers Ltd", 1995, "UK", "ARM RISC"),)]

# %% [markdown]
# Putting a limit to the number of results is a good practice that prevents queries from retrieving too many results and becoming too large to handle. A common pattern when potentially long queries are issued is to provide _pagination_ options, so that the results can be retrieved in chunks. In interactive or web applications users are given the option to move forward or backwards on the results in increments of a give page size.

# %% [markdown]
# Implementing pagination of query results involves setting a page size with the limit() method, and indicating at which position to start retrieving results.

# %%
q = select(Product).order_by(Product.name).where(Product.name > "A7000").limit(3)
session.execute(q).all()
# Out:
# [(Product(84, "ABC 80", "Luxor", 1978, "Sweden", "Z80"),),
#  (Product(62, "AGAT-9", "AGAT", 1984, "USSR", "Native/Apple II compatible"),),
#  (Product(131, "Aamber Pegasus", "Technosys", 1984, "New Zealand", "6809"),)]

# %%
q = select(Product).order_by(Product.name).limit(3).offset(6)
session.scalars(q).all()
# Out:
# [Product(5, "Acorn Archimedes", "Acorn Computers Ltd", 1987, "UK", "ARM RISC"),
#  Product(1, "Acorn Atom", "Acorn Computers Ltd", 1980, "UK", "6502"),
#  Product(55, "Alpha", "Didaktik", 1986, "Czechoslovakia", "Z80")]

# %% [markdown]
# q = select(Product).order_by(Product.name).limit(3).offset(16)
# session.scalars(q).all()

# %%
q = select(Product).where(Product.id == 23)
session.scalar(q)
# Out:
# Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80")

# %% [markdown]
# This is such a common query that SQLAlchemy implements a shortcut for it.

# %%
session.get(Product, 23)
# Out:
# Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80")

# %% [markdown]
# ## Constraints
#
# Another good database design practice is to assign appropriate constraints to columns. The Product model already has a constraint called PRIMARY KEY, which is enabled on the id column with the primary_key=True option. This names the id column as the primary key of the products table. Besides PRIMARY KEY, two other commonly used constraints are UNIQUE and NOT NULL. A column that has a UNIQUE constraint does not allow duplicated values. In the Product model, this would be a good choice for the name column, to ensure that there are no two products with the same name. To add this constraint to a column, the unique=True option is used with SQLAlchemy. The NOT NULL constraint prevents a column from ever having an empty or undefined value. This constraint can also be thought of in reverse, by saying that columns that do not have the NOT NULL constraint are considered optional. Columns defined with the Mapped[t] typing syntax get the NOT NULL constraint by default, and to create a column that is allowed to have NULL values, the type hint should be changed to Mapped[Optional[t]]. The country and cpu can be considered optional at this point, but as always, this may need to change as the role of these columns is better defined.

# %%
p = session.get(Product, 23)
p
# Out:
# Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80")

# %%
session.delete(p)
session.commit()

# %%
p = session.get(Product, 23)
print(p)
# Out:
# None

# %% [markdown]
# ## Exercises
#
# Many of the chapters in this book include a list of exercises that can help you solidfy the knowledge you acquired in the chapter. Solutions to all exercises are provided at the end of the book.
#
# Before you attempt to solve these exercises, make sure that you hae all the products imported. If you are in doubt that you have a complete database you can run the importer script once again:

# %% [markdown]
# ```bash
# uv run import_products.py
# ```

# %%
p = session.get(Product, 23)
print(p)
# Out:
# Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80")

# %%
from db import Session
from models import Product
session = Session()

# %% [markdown]
# Start a Python session and write queries that return the following information:

# %% [markdown]
# 1. The first three products in alphabetical order built in the year 1983.

# %%
q = (select(Product).where(Product.year == 1983)
     .order_by(Product.name)
     .limit(3)
)
results = session.execute(q).all()
for r in results:
    print(r)
# Out:
# (Product(17, "Apple IIe", "Apple Computer", 1983, "USA", "6502"),)
# (Product(85, "Aquarius", "Mattel", 1983, "USA", "Z80"),)
# (Product(26, "Atari 1200XL", "Atari, Inc.", 1983, "USA", "6502"),)

# %% [markdown]
# 2. Products that use the "Z80" CPU or any of its clones. Assume that all products based on this CPU have hte word "Z80" in the cpu column.

# %%
q = select(Product).where(Product.cpu.ilike("%Z80%"))
results = session.execute(q).all()
for r in results:
    print(r)
# Out:
# (Product(7, "CPC 464", "Amstrad", 1984, "UK", "Z80"),)
# (Product(8, "CPC 664", "Amstrad", 1984, "UK", "Z80"),)
# (Product(9, "CPC 6128", "Amstrad", 1984, "UK", "Z80"),)
# (Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),)
# (Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),)
# (Product(12, "PCW", "Amstrad", 1985, "UK", "Z80"),)
# (Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80"),)
# (Product(34, "Bally Brain", "Bally Consumer Products", 1979, "USA", "Z80"),)
# (Product(35, "Bally Astrocade", "Bally Consumer Products", 1977, "USA", "Z80"),)
# (Product(36, "CoBra", "Brasov Computer", 1986, "Romania", "Z80"),)
# (Product(37, "Lynx", "Camputers", 1983, "UK", "Z80"),)
# (Product(38, "Coleco Adam", "Coleco", 1983, "USA", "Z80"),)
# (Product(47, "Commodore 128", "Commodore", 1985, "USA", "8502 (6502) / Z80"),)
# (Product(51, "VTech Laser 200", "Vtech", 1985, "Hong Kong", "Z80"),)
# (Product(52, "Video Genie", "EACA", 1980, "Hong Kong", "Z80"),)
# (Product(53, "Colour Genie", "EACA", 1983, "Hong Kong", "Z80"),)
# (Product(54, "Rabbit RX83", "Rabbit", 1983, "Hong Kong", "Z80"),)
# (Product(55, "Alpha", "Didaktik", 1986, "Czechoslovakia", "Z80"),)
# (Product(56, "Beta", "Didaktik", 1986, "Czechoslovakia", "Z80"),)
# (Product(57, "Gama", "Didaktik", 1987, "Czechoslovakia", "Z80"),)
# (Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),)
# (Product(65, "Exidy Sorcerer", "Exidy", 1978, "USA", "Z80"),)
# (Product(66, "Enterprise 64", "Intelligent Software", 1985, "UK", "Z80"),)
# (Product(67, "Enterprise 128", "Intelligent Software", 1985, "UK", "Z80"),)
# (Product(68, "Lambda 8300", "Lambda Electronics", 1985, "Hong Kong", "Z80"),)
# (Product(72, "Grundy NewBrain", "Grundy Business Systems", 1982, "UK", "Z80"),)
# (Product(73, "Gradiente Expert", "Gradiente", 1985, "Brazil", "Z80"),)
# (Product(79, "Hobbit", "Intercompex", 1990, "USSR", "Z80 compatible"),)
# (Product(83, "Jupiter ACE", "Jupiter Cantab", 1982, "UK", "Z80"),)
# (Product(84, "ABC 80", "Luxor", 1978, "Sweden", "Z80"),)
# (Product(85, "Aquarius", "Mattel", 1983, "USA", "Z80"),)
# (Product(87, "MTX500", "Memotech", 1983, "UK", "Z80"),)
# (Product(88, "MTX512", "Memotech", 1983, "UK", "Z80"),)
# (Product(89, "RS128", "Memotech", 1983, "UK", "Z80"),)
# (Product(90, "MicroBee", "Microbee Systems", 1983, "Australia", "Z80"),)
# (Product(91, "CCE MC-1000", "Comércio de Componentes Eletrônicos", 1985, "Brazil", "Z80"),)
# (Product(92, "TK82C", "Microdigital Eletronica", 1985, "Brazil", "Z80"),)
# (Product(93, "SAM Coupé", "Miles Gordon Technology", 1989, "UK", "Z80"),)
# (Product(96, "PC-6000", "NEC Home Electronics", 1981, "Japan", "Z80"),)
# (Product(97, "PC-8800", "NEC", 1981, "Japan", "Z80"),)
# (Product(101, "TRS-80 Model I", "Radio Shack", 1977, "USA", "Z80"),)
# (Product(110, "P2000", "Philips", 1980, "Netherlands", "Z80"),)
# (Product(111, "G7480", "Philips", 1983, "Netherlands", "Z80"),)
# (Product(118, "KC 85", "VEB Robotron", 1984, "East Germany", "Z80 compatible"),)
# (Product(119, "KC 87", "VEB Robotron", 1987, "East Germany", "Z80 compatible"),)
# (Product(120, "Z1013", "VEB Robotron", 1985, "East Germany", "Z80 compatible"),)
# (Product(121, "SC-3000", "Sega", 1983, "Japan", "Z80 compatible"),)
# (Product(122, "MZ", "Sharp", 1979, "Japan", "Z80 compatible"),)
# (Product(123, "Sharp X1", "Sharp", 1982, "Japan", "Z80 compatible"),)
# (Product(125, "ZX80", "Sinclair Research", 1980, "UK", "Z80"),)
# (Product(126, "ZX81", "Sinclair Research", 1981, "UK", "Z80"),)
# (Product(127, "ZX Spectrum", "Sinclair Research", 1982, "UK", "Z80"),)
# (Product(129, "Sord M200 Smart Home Computer", "Sord Computer Corporation", 1977, "Japan", "Z80"),)
# (Product(130, "Sord M5", "Sord Computer Corporation", 1982, "Japan", "Z80"),)
# (Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),)
# (Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),)
# (Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80"),)
# (Product(141, "Timex Computer 2048", "Timex Sinclair", 1984, "Portugal", "Z80"),)
# (Product(142, "Timex Computer 2068", "Timex Sinclair", 1983, "USA/UK/Portugal", "Z80"),)
# (Product(143, "Komputer 2086", "Timex Sinclair", 1986, "Portugal/Poland", "Z80"),)
# (Product(147, "TVC", "Videoton", 1986, "Hungary", "Z80"),)
# (Product(148, "West PC-800", "West Computer AS", 1984, "Norway", "6502, Z80"),)
# (Product(149, "GEM 1000", "GEM", 1985, "Belgium", "Z80"),)

# %% [markdown]
# 3. Products that use either the "Z80" or the "6502" CPUs, or any of its clones, built before 1990, sorted alphabetically by name.

# %%
from sqlalchemy import or_
q = (select(Product).where(or_(
    Product.cpu.ilike("%Z80%"),
    Product.cpu.ilike("%6502")
    ))
    .order_by(Product.name)
)
results = session.execute(q).all()
for r in results:
    print(r)
# Out:
# (Product(10, "464 Plus", "Amstrad", 1990, "UK", "Z80"),)
# (Product(11, "6128 Plus", "Amstrad", 1990, "UK", "Z80"),)
# (Product(84, "ABC 80", "Luxor", 1978, "Sweden", "Z80"),)
# (Product(1, "Acorn Atom", "Acorn Computers Ltd", 1980, "UK", "6502"),)
# (Product(55, "Alpha", "Didaktik", 1986, "Czechoslovakia", "Z80"),)
# (Product(16, "Apple II", "Apple Computer", 1977, "USA", "6502"),)
# (Product(20, "Apple II Plus", "Apple Computer", 1979, "USA", "6502"),)
# (Product(17, "Apple IIe", "Apple Computer", 1983, "USA", "6502"),)
# (Product(85, "Aquarius", "Mattel", 1983, "USA", "Z80"),)
# (Product(26, "Atari 1200XL", "Atari, Inc.", 1983, "USA", "6502"),)
# (Product(24, "Atari 400", "Atari, Inc.", 1979, "USA", "6502"),)
# (Product(27, "Atari 600XL", "Atari, Inc.", 1983, "USA", "6502"),)
# (Product(25, "Atari 800", "Atari, Inc.", 1979, "USA", "6502"),)
# (Product(28, "Atari 800XL", "Atari, Inc.", 1983, "USA", "6502"),)
# (Product(2, "BBC Micro", "Acorn Computers Ltd", 1981, "UK", "6502"),)
# (Product(35, "Bally Astrocade", "Bally Consumer Products", 1977, "USA", "Z80"),)
# (Product(34, "Bally Brain", "Bally Consumer Products", 1979, "USA", "Z80"),)
# (Product(56, "Beta", "Didaktik", 1986, "Czechoslovakia", "Z80"),)
# (Product(91, "CCE MC-1000", "Comércio de Componentes Eletrônicos", 1985, "Brazil", "Z80"),)
# (Product(14, "CEC-I Zhonghua", "Tsinghua University", 1986, "China", "6502"),)
# (Product(7, "CPC 464", "Amstrad", 1984, "UK", "Z80"),)
# (Product(9, "CPC 6128", "Amstrad", 1984, "UK", "Z80"),)
# (Product(8, "CPC 664", "Amstrad", 1984, "UK", "Z80"),)
# (Product(23, "CT-80", "Aster Computers", 1982, "Netherlands", "Z80"),)
# (Product(36, "CoBra", "Brasov Computer", 1986, "Romania", "Z80"),)
# (Product(38, "Coleco Adam", "Coleco", 1983, "USA", "Z80"),)
# (Product(53, "Colour Genie", "EACA", 1983, "Hong Kong", "Z80"),)
# (Product(47, "Commodore 128", "Commodore", 1985, "USA", "8502 (6502) / Z80"),)
# (Product(60, "Dubna 48K", "Dubna", 1991, "USSR", "Z80 (compatible)"),)
# (Product(3, "Electron", "Acorn Computers Ltd", 1983, "UK", "6502"),)
# (Product(67, "Enterprise 128", "Intelligent Software", 1985, "UK", "Z80"),)
# (Product(66, "Enterprise 64", "Intelligent Software", 1985, "UK", "Z80"),)
# (Product(65, "Exidy Sorcerer", "Exidy", 1978, "USA", "Z80"),)
# (Product(69, "Franklin ACE", "Franklin Computer Corporation", 1982, "USA", "6502"),)
# (Product(111, "G7480", "Philips", 1983, "Netherlands", "Z80"),)
# (Product(149, "GEM 1000", "GEM", 1985, "Belgium", "Z80"),)
# (Product(108, "Galeb", "PEL Varaždin", 1981, "Croatia", "6502"),)
# (Product(57, "Gama", "Didaktik", 1987, "Czechoslovakia", "Z80"),)
# (Product(73, "Gradiente Expert", "Gradiente", 1985, "Brazil", "Z80"),)
# (Product(72, "Grundy NewBrain", "Grundy Business Systems", 1982, "UK", "Z80"),)
# (Product(79, "Hobbit", "Intercompex", 1990, "USSR", "Z80 compatible"),)
# (Product(115, "IMKO-1", "Pravetz", 1980, "Bulgaria", "6502"),)
# (Product(83, "Jupiter ACE", "Jupiter Cantab", 1982, "UK", "Z80"),)
# (Product(118, "KC 85", "VEB Robotron", 1984, "East Germany", "Z80 compatible"),)
# (Product(119, "KC 87", "VEB Robotron", 1987, "East Germany", "Z80 compatible"),)
# (Product(143, "Komputer 2086", "Timex Sinclair", 1986, "Portugal/Poland", "Z80"),)
# (Product(68, "Lambda 8300", "Lambda Electronics", 1985, "Hong Kong", "Z80"),)
# (Product(37, "Lynx", "Camputers", 1983, "UK", "Z80"),)
# (Product(87, "MTX500", "Memotech", 1983, "UK", "Z80"),)
# (Product(88, "MTX512", "Memotech", 1983, "UK", "Z80"),)
# (Product(122, "MZ", "Sharp", 1979, "Japan", "Z80 compatible"),)
# (Product(90, "MicroBee", "Microbee Systems", 1983, "Australia", "Z80"),)
# (Product(94, "Microprofessor III", "Multitech", 1983, "Taiwan", "6502"),)
# (Product(109, "Orao", "PEL Varaždin", 1984, "Croatia", "6502"),)
# (Product(105, "Oric 1", "Tangerine Computer Systems", 1983, "UK", "6502"),)
# (Product(106, "Oric Atmos", "Tangerine Computer Systems", 1984, "UK", "6502"),)
# (Product(107, "Oric Telestrat", "Tangerine Computer Systems", 1986, "UK", "6502"),)
# (Product(110, "P2000", "Philips", 1980, "Netherlands", "Z80"),)
# (Product(96, "PC-6000", "NEC Home Electronics", 1981, "Japan", "Z80"),)
# (Product(97, "PC-8800", "NEC", 1981, "Japan", "Z80"),)
# (Product(12, "PCW", "Amstrad", 1985, "UK", "Z80"),)
# (Product(39, "PET", "Commodore", 1977, "USA", "6502"),)
# (Product(114, "Pravetz 8D", "Pravetz", 1982, "Bulgaria", "6502"),)
# (Product(89, "RS128", "Memotech", 1983, "UK", "Z80"),)
# (Product(54, "Rabbit RX83", "Rabbit", 1983, "Hong Kong", "Z80"),)
# (Product(93, "SAM Coupé", "Miles Gordon Technology", 1989, "UK", "Z80"),)
# (Product(121, "SC-3000", "Sega", 1983, "Japan", "Z80 compatible"),)
# (Product(123, "Sharp X1", "Sharp", 1982, "Japan", "Z80 compatible"),)
# (Product(129, "Sord M200 Smart Home Computer", "Sord Computer Corporation", 1977, "Japan", "Z80"),)
# (Product(130, "Sord M5", "Sord Computer Corporation", 1982, "Japan", "Z80"),)
# (Product(92, "TK82C", "Microdigital Eletronica", 1985, "Brazil", "Z80"),)
# (Product(101, "TRS-80 Model I", "Radio Shack", 1977, "USA", "Z80"),)
# (Product(147, "TVC", "Videoton", 1986, "Hungary", "Z80"),)
# (Product(141, "Timex Computer 2048", "Timex Sinclair", 1984, "Portugal", "Z80"),)
# (Product(142, "Timex Computer 2068", "Timex Sinclair", 1983, "USA/UK/Portugal", "Z80"),)
# (Product(138, "Timex Sinclair 1000", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),)
# (Product(139, "Timex Sinclair 1500", "Timex Sinclair", 1982, "USA/UK/Portugal", "Z80"),)
# (Product(140, "Timex Sinclair 2048", "Timex Sinclair", 1984, "USA/UK/Portugal", "Z80"),)
# (Product(40, "VIC-20", "Commodore", 1980, "USA", "6502"),)
# (Product(51, "VTech Laser 200", "Vtech", 1985, "Hong Kong", "Z80"),)
# (Product(52, "Video Genie", "EACA", 1980, "Hong Kong", "Z80"),)
# (Product(148, "West PC-800", "West Computer AS", 1984, "Norway", "6502, Z80"),)
# (Product(120, "Z1013", "VEB Robotron", 1985, "East Germany", "Z80 compatible"),)
# (Product(127, "ZX Spectrum", "Sinclair Research", 1982, "UK", "Z80"),)
# (Product(125, "ZX80", "Sinclair Research", 1980, "UK", "Z80"),)
# (Product(126, "ZX81", "Sinclair Research", 1981, "UK", "Z80"),)

# %% [markdown]
# 4. The manufacturers that built products in the 1980s.

# %%
q = (select(Product.manufacturer)
     .where(Product.year.between(1980,1981))
     .distinct()
            )

session.execute(q).all()
# Out:
# [('Acorn Computers Ltd',),
#  ('Commodore',),
#  ('Data Applications International',),
#  ('EACA',),
#  ('Radio Shack',),
#  ('Philips',),
#  ('Pravetz',),
#  ('Sinclair Research',),
#  ('NEC Home Electronics',),
#  ('NEC',),
#  ('PEL Varaždin',),
#  ('Progeni Systems / Polycorp',)]
