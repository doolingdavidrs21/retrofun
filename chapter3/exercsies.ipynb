# %% [markdown]
# # Exercises
#
# Now is your chance to practice some one-to-many relationship queries. Before starting, run the `import_products.py` script to restore any products or manufacturers you may have deleted. Then open a Python session and write queries that return:
#
# 1. The list of products made by IBM and Texas Instruments

# %%
from db import Session
from models import Product, Manufacturer
session = Session()

# %%
from sqlalchemy import select, or_
q = (select(Manufacturer.products
).where(or_(Manufacturer.name.ilike("%IBM%"), Manufacturer.name.ilike("%Texas%Instr%"))
))

print(q)
# Out:
# SELECT manufacturers.id = products.manufacturer_id AS products
# FROM manufacturers, products
# WHERE lower(manufacturers.name) LIKE lower(:name_1) OR lower(manufacturers.name) LIKE lower(:name_2)

# %%
session.execute(q).all()
# Out:
# 2026-01-26 16:35:21,556 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-26 16:35:21,565 INFO sqlalchemy.engine.Engine SELECT manufacturers.id = products.manufacturer_id AS products
# FROM manufacturers, products
# WHERE lower(manufacturers.name) LIKE lower(?) OR lower(manufacturers.name) LIKE lower(?)
# 2026-01-26 16:35:21,567 INFO sqlalchemy.engine.Engine [generated in 0.00220s] ('%IBM%', '%Texas%Instr%')
# /tmp/ipykernel_101862/3999432070.py:1: SAWarning: SELECT statement has a cartesian product between FROM element(s) "products" and FROM element "manufacturers".  Apply join condition(s) between each element to resolve.
#   session.execute(q).all()
# [(False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (True,),
#  (True,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (True,),
#  (True,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,)]
