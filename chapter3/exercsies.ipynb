# %% [markdown]
# # Exercises
#
# Now is your chance to practice some one-to-many relationship queries. Before starting, run the `import_products.py` script to restore any products or manufacturers you may have deleted. Then open a Python session and write queries that return:
#
# 1. The list of products made by IBM and Texas Instruments

# %%
from db import Session
from models import Product, Manufacturer
session = Session()

# %%
from sqlalchemy import select, or_
q = (select(
    Product).join(Manufacturer.products)
    .where(or_(Manufacturer.name.ilike("%IBM%"), Manufacturer.name.ilike("%Texas%Inst%")))
)
session.execute(q).all()
# Out:
# 2026-01-26 16:53:17,758 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer_id, products.year, products.country, products.cpu
# FROM manufacturers JOIN products ON manufacturers.id = products.manufacturer_id
# WHERE lower(manufacturers.name) LIKE lower(?) OR lower(manufacturers.name) LIKE lower(?)
# 2026-01-26 16:53:17,762 INFO sqlalchemy.engine.Engine [generated in 0.00469s] ('%IBM%', '%Texas%Inst%')
# [(Product(75, "PCjr", "Manufacturer(34, "IBM")", 1984, "USA", "8088"),),
#  (Product(76, "IBM PS/1", "Manufacturer(34, "IBM")", 1990, "USA", "8088"),),
#  (Product(132, "TI-99/4", "Manufacturer(66, "Texas Instruments")", 1979, "USA", "TMS 9900"),),
#  (Product(133, "TI-99/4A", "Manufacturer(66, "Texas Instruments")", 1979, "USA", "TMS 9900"),)]

# %% [markdown]
# 2. Manufacturers that operate in Brazil

# %%
from sqlalchemy import select, or_
q = (select(
    Product.country, Manufacturer).join(Product.manufacturer)
    .where(Product.country.ilike("%Brazil%"))
)
session.execute(q).all()
# Out:
# 2026-01-26 16:54:39,121 INFO sqlalchemy.engine.Engine SELECT products.country, manufacturers.id, manufacturers.name
# FROM products JOIN manufacturers ON manufacturers.id = products.manufacturer_id
# WHERE lower(products.country) LIKE lower(?)
# 2026-01-26 16:54:39,124 INFO sqlalchemy.engine.Engine [generated in 0.00244s] ('%Brazil%',)
# [('Brazil', Manufacturer(32, "Gradiente")),
#  ('Brazil', Manufacturer(46, "Comércio de Componentes Eletrônicos")),
#  ('Brazil', Manufacturer(47, "Microdigital Eletronica")),
#  ('Brazil', Manufacturer(59, "Prológica"))]

# %% [markdown]
# 3. Products that have a manufacturer that has the word "Research" in their name.

# %%
from sqlalchemy import select
q = (select(
    Product).join(Product.manufacturer)
    .where(Manufacturer.name.ilike("%Research%"))
)
session.execute(q).all()
# Out:
# 2026-01-26 16:57:10,168 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.manufacturer_id, products.year, products.country, products.cpu
# FROM products JOIN manufacturers ON manufacturers.id = products.manufacturer_id
# WHERE lower(manufacturers.name) LIKE lower(?)
# 2026-01-26 16:57:10,172 INFO sqlalchemy.engine.Engine [generated in 0.00461s] ('%Research%',)
# 2026-01-26 16:57:10,182 INFO sqlalchemy.engine.Engine SELECT manufacturers.id AS manufacturers_id, manufacturers.name AS manufacturers_name
# FROM manufacturers
# WHERE manufacturers.id = ?
# 2026-01-26 16:57:10,185 INFO sqlalchemy.engine.Engine [cached since 899.8s ago] (63,)
# [(Product(125, "ZX80", "Manufacturer(63, "Sinclair Research")", 1980, "UK", "Z80"),),
#  (Product(126, "ZX81", "Manufacturer(63, "Sinclair Research")", 1981, "UK", "Z80"),),
#  (Product(127, "ZX Spectrum", "Manufacturer(63, "Sinclair Research")", 1982, "UK", "Z80"),),
#  (Product(128, "Sinclair QL", "Manufacturer(63, "Sinclair Research")", 1984, "UK", "68008"),)]
